# %% [markdown]
# ### Nous allons prendre quelques données de la phase 1 et ajouter à celles de la phase 2 tout en essayant d'avoir un rapport 1/10 et 9/10 entre les classes
#
# En plus claire voici l'algorithme que nous suivons:
#
# - Concatener tous les articles de la phase 1 et ceux de la phase 2
# - Conserver les articles de types VS tels qu'ils sont, conserver aussi les NVS de la phase 2
# - Piocher dans les articles de la phase 1 (considérés comme NVS) une quantité qui aidera à avoir une proportion 1/10 de VS et 9/10 de NVS

# %%
import pandas as pd 

# les données de la phase 1
data1 = pd.read_csv("data/articles_selectionnes_umap_et_kmeans.csv", keep_default_na=False)

# les données de la phase 2
data2 = pd.read_csv("data/articles_SA&SV.csv", keep_default_na=False)

# %% [markdown]
# On va conserver les articles VS que nous avons eu à la phase 2

# %%
data1.columns
# Out:
# Index(['title', 'text', 'thematique', 'Maladie', 'text_sans_html',
#        'text_concat', 'clean_text', 'x', 'y', 'z', 'cluster', 'dist'],
#       dtype='object')

# %%
data2.columns
# Out:
# Index(['url', 'title', 'text', 'type_article', 'thematique', 'pertinent',
#        'word_count'],
#       dtype='object')

# %%
# Récupérer les colonnes qui nous interssent : on prend les textes néttoyés de la phase 1

data1 = data1[["clean_text", "thematique"]]

# renommer afin d'harmoniser 
data1.rename(columns={"clean_text":"text"}, inplace=True)

# %%
# Faire pareil avec les données de la phase 2
data2["text_concat"] = data2["title"] + " " + data2["text"]

data2 = data2[["text_concat", "type_article", "thematique"]]

data2.rename(columns={"text_concat":"text"}, inplace=True)

# %%
import pandas as pd

# === 1. Marquer tous les articles de phase 1 comme NVS
data1["type_article"] = "NVS"

# === 2. Colonnes d’intérêt
columns = ["text", "type_article", "thematique"]
data1 = data1[columns]
data2 = data2[columns]

# === 3. Filtrer uniquement SA / SV
data1 = data1[data1["thematique"].isin(["SA", "SV"])]
data2 = data2[data2["thematique"].isin(["SA", "SV"])]

# === 4. Séparer les types dans la phase 2
vs_phase2 = data2[data2["type_article"] == "VS"]
nvs_phase2 = data2[data2["type_article"] == "NVS"]

# === 5. Conserver tous les VS et NVS de la phase 2
base_data = pd.concat([vs_phase2, nvs_phase2], ignore_index=True)

# === 6. Calcul du nombre total requis pour avoir VS = 1/10 du total
n_vs = len(vs_phase2)
n_total_target = n_vs * 10
n_nvs_target = n_total_target - n_vs

# === 7. NVS actuels (phase 2 uniquement pour l'instant)
n_nvs_phase2 = len(nvs_phase2)
n_nvs_needed = n_nvs_target - n_nvs_phase2

# === 8. Si besoin, on pioche dans les NVS de la phase 1
if n_nvs_needed > 0:
    if n_nvs_needed > len(data1):
        raise ValueError(
            f"Pas assez de NVS dans la phase 1 : il faut {n_nvs_needed}, mais seulement {len(data1)} disponibles."
        )
    nvs_from_phase1 = data1.sample(n=n_nvs_needed, random_state=42)
    final_data = pd.concat([base_data, nvs_from_phase1], ignore_index=True)
else:
    final_data = base_data.copy()
    print("Assez de NVS déjà présents, aucun ajout depuis la phase 1 nécessaire.")

# === 9. Vérifications
print("\nRépartition VS/NVS :")
print(final_data["type_article"].value_counts(normalize=True).round(2))

print("\nRépartition des thématiques :")
print(final_data["thematique"].value_counts())

print(f"\nTotal articles : {len(final_data)} (VS: {n_vs}, NVS: {len(final_data) - n_vs})")
# Out:
# Répartition VS/NVS :
# type_article
# NVS    0.9
# VS     0.1
# Name: proportion, dtype: float64
#
# Répartition des thématiques :
# thematique
# SV    1422
# SA    1068
# Name: count, dtype: int64
#
# Total articles : 2490 (VS: 249, NVS: 2241)

# %%
final_data["type_article"].value_counts()
# Out:
# type_article
# NVS    2241
# VS      249
# Name: count, dtype: int64

# %% [markdown]
# ### Traitement des textes

# %%
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from string import punctuation

# Initialisation
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
custom_stopwords = {'et', 'al'} # Les expressions que nous avons retrouvées en grande quantité lors de nos expérimentations et nous avons décidé de ne pas les conserver 


def nettoyer_texte(texte):
    """
    Nettoie un texte brut :
    2. Tokenisation
    3. Nettoyage caractères spéciaux
    4. Suppression stopwords, ponctuation, custom_stopwords
    5. Lemmatisation
    """
    
    # Étape 2 : tokenisation
    tokens = word_tokenize(texte)

    # Étape 3-6 : nettoyage
    tokens_nettoyes = []
    for token in tokens:
        token = token.lower()
        token = re.sub(r'\s+', '', token)
        token = re.sub(r'[^a-zàâçéèêëîïôûùüÿñæœ]', '', token)

        if (
            token
            and token not in stop_words
            and token not in punctuation
            and token not in custom_stopwords
        ):
            token = lemmatizer.lemmatize(token)
            tokens_nettoyes.append(token)

    return tokens_nettoyes # On retourne d'abord les tokens afin de pouvoir visualiser le wordcloud des articles 

# Ensuite on fera la jointures des tokens pour former les textes nettoyés

# %%
# Application 
final_data["tokens_clean"] = final_data["text"].apply(nettoyer_texte)

# %%
# Jointure des tokens pour former des textes prêts à être utiliser pour la classification
final_data["text_clean"] = final_data["tokens_clean"].apply(lambda tokens: " ".join(tokens))

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np

# Fusionnons tous les tokens dans une liste 

all_tokens = [token for tokens in final_data["tokens_clean"] for token in tokens]

# Calcul de la fréquence des mots 
token_counts = Counter(all_tokens)

# Affichage du word_cloud
wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white',
    max_words=200
).generate_from_frequencies(token_counts)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud des mots nettoyés ", fontsize=14)
plt.show()

# %% [markdown]
# ### Sauvegarde de ce jeu de données pour nos classifications

# %%
final_data = final_data[["text", "tokens_clean", "text_clean", "type_article", "thematique"]]

# %%
final_data.to_csv("data/data_classification_2.csv", index=False)

# %%
final_data.head()
# Out:
#                                                 text  \
# 0  Microbial Community Composition Associated wit...
# 1  Plant Pathogenic and Endophytic Colletotrichum...
# 2  Lethal Bronzing: What you should know about th...
# 3  Leaffooted Bug Damage in Almond Orchards Leaff...
# 4  Kebbi govt battles mysterious disease affectin...
#
#                                         tokens_clean  \
# 0  [microbial, community, composition, associated...
# 1  [plant, pathogenic, endophytic, colletotrichum...
# 2  [lethal, bronzing, know, disease, turn, palm, ...
# 3  [leaffooted, bug, damage, almond, orchard, lea...
# 4  [kebbi, govt, battle, mysterious, disease, aff...
#
#                                           text_clean type_article thematique
# 0  microbial community composition associated pot...           VS         SV
# 1  plant pathogenic endophytic colletotrichum fru...           VS         SV
# 2  lethal bronzing know disease turn palm tree br...           VS         SV
# 3  leaffooted bug damage almond orchard leaffoote...           VS         SV
# 4  kebbi govt battle mysterious disease affecting...           VS         SV

# %%
import pandas as pd 
data = pd.read_csv("data/data_classification_2.csv", keep_default_na=False)

# %% [markdown]
# ### Appliquons TF-IDF et XGBOOST
#
# Car cette approche qui avait bien fonctionné dans nos expérimentations
#
# Nous allons utiliser les indices sauvegardés pour spliter nos données en 3

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    precision_recall_curve,
    average_precision_score
)
import matplotlib.pyplot as plt
import xgboost as xgb
import joblib
from sklearn.metrics import accuracy_score, f1_score
import os, joblib
import numpy as np

idx_train = np.load("splits_idx_train.npy")
idx_val   = np.load("splits_idx_val.npy")
idx_test  = np.load("splits_idx_test.npy")

# === 1. Données
X = data["text_clean"].astype(str).to_numpy()
y = data["type_article"].to_numpy()

# Encodage binaire (NVS = 0, VS = 1)
le = LabelEncoder()
y_enc = le.fit_transform(y)

# === 2. Split train / temp
X_train_texts, X_val_texts, X_test_texts = X[idx_train], X[idx_val], X[idx_test]
y_train, y_val, y_test = y_enc[idx_train], y_enc[idx_val], y_enc[idx_test]



# === 4. TF-IDF Vectorisation
vec = TfidfVectorizer(max_features=5000, ngram_range=(1,2))
X_train_vec = vec.fit_transform(X_train_texts)
X_val_vec   = vec.transform(X_val_texts)
X_test_vec  = vec.transform(X_test_texts)

# === 5. Modèle XGBoost avec early stopping


# Convertir en DMatrix, forme optimisée pour le modèle xgboost
dtrain = xgb.DMatrix(X_train_vec, label=y_train)
dval = xgb.DMatrix(X_val_vec, label=y_val)
dtest = xgb.DMatrix(X_test_vec)

# Paramètres du modèle
params = {
    "objective": "binary:logistic", # classification binaire
    "eval_metric": "logloss", # on regarde le logarithme de l'erreur 
    "max_depth": 5, # profondeur d'un arbre de la forêt
    "eta": 0.05, # taux d'apprentissage
    "subsample": 0.8, # taux d'échantillonnage 
    "colsample_bytree": 0.8,
    "seed": 42
}

# Initialisation du dictionnaire pour stocker les métriques
evals_result = {}

# Entraînement avec early stopping
watchlist = [(dtrain, "train"), (dval, "eval")]
bst = xgb.train(
    params,
    dtrain,
    num_boost_round=1000, # les arbres sont ajoutés de manière itérative, maintenant si l'apprentissage n'évolue pas on ajoute plus d'arbre
    evals=watchlist,
    early_stopping_rounds=10,
    evals_result=evals_result,
    verbose_eval=True
)

# === Courbes d'apprentissage (loss, accuracy, f1) ===
train_loss = evals_result['train']['logloss']
val_loss = evals_result['eval']['logloss']

# On calcule manuellement accuracy et f1 à chaque étape
train_acc, val_acc, train_f1, val_f1 = [], [], [], []

for i in range(len(train_loss)):
    # Prédictions train et val à l'itération i
    y_train_pred = (bst.predict(dtrain, iteration_range=(0, i+1)) >= 0.5).astype(int)
    y_val_pred = (bst.predict(dval, iteration_range=(0, i+1)) >= 0.5).astype(int)

    # Accuracies
    train_acc.append(accuracy_score(y_train, y_train_pred))
    val_acc.append(accuracy_score(y_val, y_val_pred))

    # F1 scores
    train_f1.append(f1_score(y_train, y_train_pred))
    val_f1.append(f1_score(y_val, y_val_pred))


# Affichage des courbes 
epochs = range(1, len(train_loss) + 1)

plt.figure(figsize=(12, 5))

# --- Courbe de perte
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, label="Train Loss", marker="o")
plt.plot(epochs, val_loss, label="Validation Loss", marker="o")
plt.xlabel("Époque")
plt.ylabel("Perte")
plt.title("Courbe de perte")
plt.legend()
plt.grid(True)

# --- Courbes Accuracy et F1
plt.subplot(1, 2, 2)
plt.plot(epochs, train_acc, label="Train Acc", marker="o")
plt.plot(epochs, val_acc, label="Validation Acc", marker="o")
plt.plot(epochs, train_f1, label="Train F1", linestyle="--", color="green")
plt.plot(epochs, val_f1, label="Validation F1", linestyle="--", color="red")
plt.xlabel("Époque")
plt.ylabel("Score")
plt.title("Courbes Accuracy / F1")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()



# Prédiction sur les données de test
y_scores = bst.predict(dtest)
y_pred = (y_scores >= 0.5).astype(int)


os.makedirs("models", exist_ok=True)  # crée le dossier si absent

bst.save_model("models/sbert_xgb.json")  # ou best_modele_melange.json si tu veux
joblib.dump(le, "models/label_encoder.pkl")


# Sauvegarde du modèle 
bst.save_model("models/best_modele_melange.json")

# Sauvegarde du vectorizer 

joblib.dump(vec, "models/vectorizer_melange.pkl")

# Rapport
print("=== Rapport de classification (TF-IDF + XGBoost) sur les données de test ===")
print(classification_report(y_test, y_pred, target_names=le.classes_))

# Matrice de confusion
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=le.classes_)
disp.plot(cmap="Blues")
plt.title("Matrice de confusion - TF-IDF + XGBoost sur les données de test")
plt.tight_layout()
plt.show()

# Courbe AUC-PR
precision, recall, _ = precision_recall_curve(y_test, y_scores)
auc_pr = average_precision_score(y_test, y_scores)

plt.figure(figsize=(7, 5))
plt.plot(recall, precision, label=f"AUC-PR = {auc_pr:.2f}", color="green")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Courbe Precision-Recall - TF-IDF + XGBoost sur les données de test")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# [0]	train-logloss:0.29589	eval-logloss:0.29890
# [1]	train-logloss:0.27148	eval-logloss:0.27545
# [2]	train-logloss:0.25265	eval-logloss:0.25953
# [3]	train-logloss:0.23572	eval-logloss:0.24434
# [4]	train-logloss:0.22112	eval-logloss:0.23101
# [5]	train-logloss:0.21010	eval-logloss:0.22005
# [6]	train-logloss:0.19758	eval-logloss:0.20809
# [7]	train-logloss:0.19030	eval-logloss:0.20184
# [8]	train-logloss:0.18035	eval-logloss:0.19291
# [9]	train-logloss:0.17188	eval-logloss:0.18514
# [10]	train-logloss:0.16378	eval-logloss:0.17734
# [11]	train-logloss:0.15611	eval-logloss:0.16951
# [12]	train-logloss:0.14924	eval-logloss:0.16346
# [13]	train-logloss:0.14300	eval-logloss:0.15773
# [14]	train-logloss:0.13729	eval-logloss:0.15265
# [15]	train-logloss:0.13150	eval-logloss:0.14775
# [16]	train-logloss:0.12647	eval-logloss:0.14297
# [17]	train-logloss:0.12108	eval-logloss:0.13787
# [18]	train-logloss:0.11656	eval-logloss:0.13414
# [19]	train-logloss:0.11265	eval-logloss:0.13025
# [20]	train-logloss:0.10847	eval-logloss:0.12656
# [21]	train-logloss:0.10544	eval-logloss:0.12383
# [22]	train-logloss:0.10215	eval-logloss:0.12046
# [23]	train-logloss:0.09854	eval-logloss:0.11712
# [24]	train-logloss:0.09503	eval-logloss:0.11332
# [25]	train-logloss:0.09210	eval-logloss:0.11068
# [26]	train-logloss:0.08903	eval-logloss:0.10838
# [27]	train-logloss:0.08615	eval-logloss:0.10676
# [28]	train-logloss:0.08363	eval-logloss:0.10479
# [29]	train-logloss:0.08095	eval-logloss:0.10284
# [30]	train-logloss:0.07822	eval-logloss:0.10022
# [31]	train-logloss:0.07583	eval-logloss:0.09785
# [32]	train-logloss:0.07352	eval-logloss:0.09644
# [33]	train-logloss:0.07152	eval-logloss:0.09471
# [34]	train-logloss:0.06921	eval-logloss:0.09268
# [35]	train-logloss:0.06725	eval-logloss:0.09134
# [36]	train-logloss:0.06525	eval-logloss:0.08965
# [37]	train-logloss:0.06344	eval-logloss:0.08805
# [38]	train-logloss:0.06167	eval-logloss:0.08646
# [39]	train-logloss:0.06005	eval-logloss:0.08556
# [40]	train-logloss:0.05818	eval-logloss:0.08344
# [41]	train-logloss:0.05647	eval-logloss:0.08167
# [42]	train-logloss:0.05474	eval-logloss:0.07965
# [43]	train-logloss:0.05333	eval-logloss:0.07845
# [44]	train-logloss:0.05190	eval-logloss:0.07709
# [45]	train-logloss:0.05075	eval-logloss:0.07618
# [46]	train-logloss:0.04948	eval-logloss:0.07500
# [47]	train-logloss:0.04839	eval-logloss:0.07424
# [48]	train-logloss:0.04705	eval-logloss:0.07264
# [49]	train-logloss:0.04599	eval-logloss:0.07203
# [50]	train-logloss:0.04492	eval-logloss:0.07111
# [51]	train-logloss:0.04398	eval-logloss:0.07038
# [52]	train-logloss:0.04312	eval-logloss:0.06995
# [53]	train-logloss:0.04225	eval-logloss:0.06934
# [54]	train-logloss:0.04117	eval-logloss:0.06829
# [55]	train-logloss:0.04020	eval-logloss:0.06707
# [56]	train-logloss:0.03946	eval-logloss:0.06645
# [57]	train-logloss:0.03850	eval-logloss:0.06511
# [58]	train-logloss:0.03773	eval-logloss:0.06460
# [59]	train-logloss:0.03699	eval-logloss:0.06375
# [60]	train-logloss:0.03626	eval-logloss:0.06323
# [61]	train-logloss:0.03553	eval-logloss:0.06267
# [62]	train-logloss:0.03481	eval-logloss:0.06214
# [63]	train-logloss:0.03414	eval-logloss:0.06154
# [64]	train-logloss:0.03342	eval-logloss:0.06065
# [65]	train-logloss:0.03284	eval-logloss:0.06024
# [66]	train-logloss:0.03225	eval-logloss:0.05993
# [67]	train-logloss:0.03163	eval-logloss:0.05922
# [68]	train-logloss:0.03111	eval-logloss:0.05880
# [69]	train-logloss:0.03054	eval-logloss:0.05839
# [70]	train-logloss:0.03004	eval-logloss:0.05790
# [71]	train-logloss:0.02945	eval-logloss:0.05735
# [72]	train-logloss:0.02900	eval-logloss:0.05718
# [73]	train-logloss:0.02860	eval-logloss:0.05699
# [74]	train-logloss:0.02815	eval-logloss:0.05645
# [75]	train-logloss:0.02769	eval-logloss:0.05592
# [76]	train-logloss:0.02734	eval-logloss:0.05566
# [77]	train-logloss:0.02692	eval-logloss:0.05540
# [78]	train-logloss:0.02649	eval-logloss:0.05526
# [79]	train-logloss:0.02614	eval-logloss:0.05504
# [80]	train-logloss:0.02575	eval-logloss:0.05471
# [81]	train-logloss:0.02536	eval-logloss:0.05437
# [82]	train-logloss:0.02507	eval-logloss:0.05430
# [83]	train-logloss:0.02466	eval-logloss:0.05423
# [84]	train-logloss:0.02430	eval-logloss:0.05403
# [85]	train-logloss:0.02400	eval-logloss:0.05377
# [86]	train-logloss:0.02366	eval-logloss:0.05354
# [87]	train-logloss:0.02331	eval-logloss:0.05353
# [88]	train-logloss:0.02300	eval-logloss:0.05305
# [89]	train-logloss:0.02269	eval-logloss:0.05303
# [90]	train-logloss:0.02248	eval-logloss:0.05321
# [91]	train-logloss:0.02224	eval-logloss:0.05329
# [92]	train-logloss:0.02201	eval-logloss:0.05311
# [93]	train-logloss:0.02182	eval-logloss:0.05314
# [94]	train-logloss:0.02155	eval-logloss:0.05289
# [95]	train-logloss:0.02127	eval-logloss:0.05268
# [96]	train-logloss:0.02101	eval-logloss:0.05260
# [97]	train-logloss:0.02082	eval-logloss:0.05240
# [98]	train-logloss:0.02053	eval-logloss:0.05232
# [99]	train-logloss:0.02031	eval-logloss:0.05216
# [100]	train-logloss:0.02010	eval-logloss:0.05217
# [101]	train-logloss:0.01986	eval-logloss:0.05218
# [102]	train-logloss:0.01965	eval-logloss:0.05228
# [103]	train-logloss:0.01945	eval-logloss:0.05228
# [104]	train-logloss:0.01928	eval-logloss:0.05237
# [105]	train-logloss:0.01903	eval-logloss:0.05224
# [106]	train-logloss:0.01882	eval-logloss:0.05217
# [107]	train-logloss:0.01859	eval-logloss:0.05207
# [108]	train-logloss:0.01838	eval-logloss:0.05199
# [109]	train-logloss:0.01813	eval-logloss:0.05181
# [110]	train-logloss:0.01796	eval-logloss:0.05205
# [111]	train-logloss:0.01775	eval-logloss:0.05191
# [112]	train-logloss:0.01757	eval-logloss:0.05201
# [113]	train-logloss:0.01736	eval-logloss:0.05205
# [114]	train-logloss:0.01716	eval-logloss:0.05205
# [115]	train-logloss:0.01702	eval-logloss:0.05205
# [116]	train-logloss:0.01686	eval-logloss:0.05189
# [117]	train-logloss:0.01670	eval-logloss:0.05176
# [118]	train-logloss:0.01657	eval-logloss:0.05151
# [119]	train-logloss:0.01640	eval-logloss:0.05160
# [120]	train-logloss:0.01624	eval-logloss:0.05154
# [121]	train-logloss:0.01608	eval-logloss:0.05156
# [122]	train-logloss:0.01595	eval-logloss:0.05140
# [123]	train-logloss:0.01579	eval-logloss:0.05146
# [124]	train-logloss:0.01567	eval-logloss:0.05150
# [125]	train-logloss:0.01550	eval-logloss:0.05140
# [126]	train-logloss:0.01536	eval-logloss:0.05140
# [127]	train-logloss:0.01522	eval-logloss:0.05135
# [128]	train-logloss:0.01512	eval-logloss:0.05135
# [129]	train-logloss:0.01500	eval-logloss:0.05129
# [130]	train-logloss:0.01489	eval-logloss:0.05126
# [131]	train-logloss:0.01475	eval-logloss:0.05127
# [132]	train-logloss:0.01464	eval-logloss:0.05118
# [133]	train-logloss:0.01450	eval-logloss:0.05122
# [134]	train-logloss:0.01433	eval-logloss:0.05124
# [135]	train-logloss:0.01425	eval-logloss:0.05115
# [136]	train-logloss:0.01415	eval-logloss:0.05117
# [137]	train-logloss:0.01401	eval-logloss:0.05121
# [138]	train-logloss:0.01389	eval-logloss:0.05114
# [139]	train-logloss:0.01377	eval-logloss:0.05107
# [140]	train-logloss:0.01367	eval-logloss:0.05121
# [141]	train-logloss:0.01356	eval-logloss:0.05127
# [142]	train-logloss:0.01344	eval-logloss:0.05125
# [143]	train-logloss:0.01334	eval-logloss:0.05127
# [144]	train-logloss:0.01322	eval-logloss:0.05125
# [145]	train-logloss:0.01313	eval-logloss:0.05107
# [146]	train-logloss:0.01305	eval-logloss:0.05095
# [147]	train-logloss:0.01297	eval-logloss:0.05079
# [148]	train-logloss:0.01288	eval-logloss:0.05071
# [149]	train-logloss:0.01277	eval-logloss:0.05072
# [150]	train-logloss:0.01266	eval-logloss:0.05079
# [151]	train-logloss:0.01255	eval-logloss:0.05071
# [152]	train-logloss:0.01244	eval-logloss:0.05067
# [153]	train-logloss:0.01233	eval-logloss:0.05068
# [154]	train-logloss:0.01223	eval-logloss:0.05071
# [155]	train-logloss:0.01215	eval-logloss:0.05071
# [156]	train-logloss:0.01209	eval-logloss:0.05076
# [157]	train-logloss:0.01201	eval-logloss:0.05076
# [158]	train-logloss:0.01192	eval-logloss:0.05065
# [159]	train-logloss:0.01183	eval-logloss:0.05068
# [160]	train-logloss:0.01176	eval-logloss:0.05071
# [161]	train-logloss:0.01169	eval-logloss:0.05073
# [162]	train-logloss:0.01163	eval-logloss:0.05075
# [163]	train-logloss:0.01157	eval-logloss:0.05066
# [164]	train-logloss:0.01151	eval-logloss:0.05065
# [165]	train-logloss:0.01143	eval-logloss:0.05056
# [166]	train-logloss:0.01134	eval-logloss:0.05050
# [167]	train-logloss:0.01129	eval-logloss:0.05042
# [168]	train-logloss:0.01121	eval-logloss:0.05041
# [169]	train-logloss:0.01114	eval-logloss:0.05049
# [170]	train-logloss:0.01108	eval-logloss:0.05050
# [171]	train-logloss:0.01102	eval-logloss:0.05027
# [172]	train-logloss:0.01095	eval-logloss:0.05002
# [173]	train-logloss:0.01087	eval-logloss:0.05000
# [174]	train-logloss:0.01081	eval-logloss:0.05008
# [175]	train-logloss:0.01075	eval-logloss:0.05001
# [176]	train-logloss:0.01069	eval-logloss:0.05016
# [177]	train-logloss:0.01062	eval-logloss:0.05019
# [178]	train-logloss:0.01056	eval-logloss:0.05023
# [179]	train-logloss:0.01048	eval-logloss:0.05030
# [180]	train-logloss:0.01039	eval-logloss:0.05039
# [181]	train-logloss:0.01034	eval-logloss:0.05043
# [182]	train-logloss:0.01029	eval-logloss:0.05040
# === Rapport de classification (TF-IDF + XGBoost) sur les données de test ===
#               precision    recall  f1-score   support
#
#          NVS       0.99      1.00      0.99       202
#           VS       1.00      0.87      0.93        23
#
#     accuracy                           0.99       225
#    macro avg       0.99      0.93      0.96       225
# weighted avg       0.99      0.99      0.99       225

# %% [markdown]
# ## Remarque
#
# Les performances ne sont plus vraiment pareilles que ce qu'on avait eu dans nos expérimentations mais ces résultats montrent tout de même que cette méthode fonctionne bien au vu de son AUC-PR.
#
# #### Cause possibles de ce changement
# - La reproductibilité de la sélection dans les articles NVS peut ne pas être respectée de manière stricte

# %% [markdown]
# ### Essayons de faire une recherche des features qui permettent à ce modèle de classer un article comme étant VS.
#
# Nous devons extraire les poids des feautures depuis le modèle, le modèle xgboost attribue des poids aux features, ici ces features correspondent aux n-grammes de notre vectorizer tf-idf

# %%
# Récupérer les scores d'importance des features (TF-IDF)
importance_scores = bst.get_score(importance_type='weight')  # ou 'gain' pour l'impact moyen sur la perte

# Map features index to their names
feature_names = vec.get_feature_names_out()

# Convertir les clés de type 'f123' -> index entier
feature_importances = {
    feature_names[int(k[1:])]: v for k, v in importance_scores.items()
}

# Trier par importance décroissante
sorted_features = sorted(feature_importances.items(), key=lambda x: x[1], reverse=True)

# Afficher les 20 mots les plus importants
print("Top 20 mots les plus influents (poids) :")
for word, score in sorted_features[:20]:
    print(f"{word} : {score}")
# Out:
# Top 20 mots les plus influents (poids) :
# disease : 118.0
# mysterious : 107.0
# unknown : 71.0
# mystery : 52.0
# said : 30.0
# block : 29.0
# could : 28.0
# may : 26.0
# new : 25.0
# also : 22.0
# target : 22.0
# found : 17.0
# using : 17.0
# group : 16.0
# illness : 16.0
# need : 15.0
# reported : 15.0
# risk : 14.0
# certain : 13.0
# pest : 13.0

# %% [markdown]
# ### Visualisation graphique

# %%
import matplotlib.pyplot as plt

top_words = sorted_features[:20]
words, scores = zip(*top_words)

plt.figure(figsize=(10, 6))
plt.barh(words[::-1], scores[::-1], color="green")
plt.xlabel("Importance")
plt.title("Top 20 mots les plus influents pour la classification (VS vs NVS)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Test
#
# #### Formons deux phrases à partir de ces mots, nettoyons ces phrases avec notre fonction de nettoyage puis appliquons une prédiction en affichant les scores de proba

# %%
# =========================
# Inference TF-IDF + XGBoost (Booster)
# =========================
import os, re, joblib, numpy as np
from typing import List, Tuple
import xgboost as xgb

# --- chemins (compatibles avec ton entraînement) ---
SAVE_DIR = "models"
VEC_PATH = os.path.join(SAVE_DIR, "vectorizer_melange.pkl")   # <- tu l'as sauvegardé ainsi
LE_PATH  = os.path.join(SAVE_DIR, "label_encoder.pkl")
XGB_BOOSTER_PATH = os.path.join(SAVE_DIR, "best_modele_melange.json")  # modèle final

# =========================
# Nettoyage identique à l'entraînement
# =========================
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from string import punctuation

nltk.download("punkt", quiet=True)
nltk.download("wordnet", quiet=True)
nltk.download("omw-1.4", quiet=True)
nltk.download("stopwords", quiet=True)

_stop_words = set(stopwords.words("english"))
_lemmatizer = WordNetLemmatizer()
_custom_stopwords = {"et", "al"}  # comme à l'entraînement

def nettoyer_texte(texte: str) -> str:
    tokens = word_tokenize(str(texte))
    out = []
    for tok in tokens:
        tok = tok.lower()
        tok = re.sub(r"\s+", "", tok)
        tok = re.sub(r"[^a-zàâçéèêëîïôûùüÿñæœ]", "", tok)  # même regex que train
        if tok and tok not in _stop_words and tok not in punctuation and tok not in _custom_stopwords:
            tok = _lemmatizer.lemmatize(tok)
            out.append(tok)
    return " ".join(out)

# =========================
# Chargements
# =========================
if not os.path.isfile(VEC_PATH):
    raise FileNotFoundError(f"Vectorizer introuvable: {VEC_PATH}")
if not os.path.isfile(LE_PATH):
    raise FileNotFoundError(f"LabelEncoder introuvable: {LE_PATH}")
if not os.path.isfile(XGB_BOOSTER_PATH):
    raise FileNotFoundError(f"Modèle XGBoost introuvable: {XGB_BOOSTER_PATH}")

vec = joblib.load(VEC_PATH)
le  = joblib.load(LE_PATH)
classes = list(le.classes_)             # ex: ["NVS", "VS"]

booster = xgb.Booster()
booster.load_model(XGB_BOOSTER_PATH)

# =========================
# Prédiction
# =========================
def predict_tfidf_xgb(
    texts: List[str],
    clean: bool = True
) -> Tuple[List[str], np.ndarray, List[str]]:
    """
    Retourne:
      - texts_used: textes (nettoyés ou bruts) passés au vectorizer
      - probs: array (N, num_classes) ordonné comme 'classes'
      - labels_pred: classes argmax
    """
    texts_used = [nettoyer_texte(t) if clean else str(t) for t in texts]

    X = vec.transform(texts_used)
    dtest = xgb.DMatrix(X)

    # Booster binaire -> proba de la classe "1"
    score_pos = booster.predict(dtest)  # shape (N,)
    # On place cette proba au bon indice ("VS"), le complément au reste ("NVS")
    if len(classes) != 2:
        raise ValueError("Ce script suppose une classification binaire (NVS/VS).")

    probs = np.zeros((len(texts), 2), dtype=float)
    try:
        vs_idx = classes.index("VS")
        nvs_idx = 1 - vs_idx
    except ValueError:
        # Si classes sont ["0","1"] par ex., on suppose que 1 == positif
        vs_idx = classes.index("1") if "1" in classes else 1
        nvs_idx = 1 - vs_idx

    probs[:, vs_idx]  = score_pos
    probs[:, nvs_idx] = 1.0 - score_pos

    pred_idx = probs.argmax(axis=1)
    labels_pred = [classes[i] for i in pred_idx]
    return texts_used, probs, labels_pred

def print_predictions(texts: List[str], probs: np.ndarray, labels_pred: List[str]):
    for i, txt in enumerate(texts):
        print("\n" + "-"*90)
        print(f"Texte : {txt}")
        print(f"-> Classe prédite : {labels_pred[i]}")
        order = np.argsort(-probs[i])
        for j in order:
            print(f"  P({classes[j]}) = {probs[i, j]:.4f}")

def classify_tfidf_xgb(texts: List[str], clean: bool = True):
    texts_used, probs, labels = predict_tfidf_xgb(texts, clean=clean)
    print_predictions(texts, probs, labels)
    return texts_used, probs, labels

# === Exemples de test ===
phrases_test = [
    "An unusual illness was detected among domestic animals, with authorities reporting several instances of an unclassified sickness in the region.",
    "The municipality revealed plans for a new public park in the city center, aiming to draw more tourists and enhance the urban landscape."
]

# IMPORTANT : tu as entraîné TF-IDF sur "text_clean" -> garde clean=True ici
_ = classify_tfidf_xgb(phrases_test, clean=True)
# Out:
# ------------------------------------------------------------------------------------------
# Texte : An unusual illness was detected among domestic animals, with authorities reporting several instances of an unclassified sickness in the region.
# -> Classe prédite : NVS
#   P(NVS) = 0.9967
#   P(VS) = 0.0033
#
# ------------------------------------------------------------------------------------------
# Texte : The municipality revealed plans for a new public park in the city center, aiming to draw more tourists and enhance the urban landscape.
# -> Classe prédite : NVS
#   P(NVS) = 0.9996
#   P(VS) = 0.0004

# %% [markdown]
# ### Commentaire
#
# Le terme *desease* semble avoir une très grande influence sur la prédiction du type de l'article mais lorqu'on le met seule dans une phrase, ce n'est pas suffisant pour dire que l'article parle de veille syndromique

# %% [markdown]
# ### Essayons d'appliquer la suppression des noms de maladie dans les articles et reprennons la classification et le test

# %%
NOMS_MALADIE = [
    "fusarium oxysporum tropical", "hlb", "xylella fastidiosa", "dengue",
    "african swine fever", "avian influenza", "bluetongue",
    "classical swine fever", "foot and mouth disease", "lumpy skin disease",
    "peste des petits ruminants", "schmallengberg virus", "chikungunya", "cholera",
    "coronavirus", "cwd", "disease", "distemper", "echinococcus", "eee", "ehv",
    "fungus", "legionella", "mad cow", "newcastle", "parvovirus", "rabies",
    "rhd", "schmallenberg virus", "suspicion", "unknown",
    "vesicular stomatitis", "west nile", "zika"
]

MALADIE_PATTERN = re.compile("|".join(map(re.escape, NOMS_MALADIE)), flags=re.IGNORECASE)
URL_PATTERN = re.compile(r'http\S+|www\S+|<a .*?>|</a>|<.*?>', flags=re.IGNORECASE)


def supprimer_maladie(texte):
    if not isinstance(texte, str):
        return ""
    texte = URL_PATTERN.sub(" ", texte)
    texte = MALADIE_PATTERN.sub(" ", texte)
    return texte

# %%
data["text"] = data["text"].apply(supprimer_maladie)

data["tokens_clean"] = data["text"].apply(nettoyer_texte)

data["text_clean"] = data["tokens_clean"].apply(lambda tokens: " ".join(tokens))

# %% [markdown]
# On relance TF-IDF et XG-BOOST

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    precision_recall_curve,
    average_precision_score
)
import matplotlib.pyplot as plt
import xgboost as xgb
import joblib
from sklearn.metrics import accuracy_score, f1_score
import os, joblib


# === 1. Données
X = data["text_clean"]
y = data["type_article"]

# Encodage binaire (NVS = 0, VS = 1)
le = LabelEncoder()
y_enc = le.fit_transform(y)

# === 2. Split train / temp
X_train_texts, X_temp_texts, y_train, y_temp = train_test_split(
    X, y_enc, test_size=0.3, stratify=y_enc, random_state=42
)

# === 3. Split temp → validation / test
X_val_texts, X_test_texts, y_val, y_test = train_test_split(
    X_temp_texts, y_temp, test_size=0.3, stratify=y_temp, random_state=42
)

# === 4. TF-IDF Vectorisation
vectorizer = TfidfVectorizer(max_features=5000, ngram_range=(1, 2))
X_train_vec = vectorizer.fit_transform(X_train_texts)
X_val_vec = vectorizer.transform(X_val_texts)
X_test_vec = vectorizer.transform(X_test_texts)

# === 5. Modèle XGBoost avec early stopping


# Convertir en DMatrix, forme optimisée pour le modèle xgboost
dtrain = xgb.DMatrix(X_train_vec, label=y_train)
dval = xgb.DMatrix(X_val_vec, label=y_val)
dtest = xgb.DMatrix(X_test_vec)

# Paramètres du modèle
params = {
    "objective": "binary:logistic", # classification binaire
    "eval_metric": "logloss", # on regarde le logarithme de l'erreur 
    "max_depth": 5, # profondeur d'un arbre de la forêt
    "eta": 0.05, # taux d'apprentissage
    "subsample": 0.8, # taux d'échantillonnage 
    "colsample_bytree": 0.8,
    "seed": 42
}

# Initialisation du dictionnaire pour stocker les métriques
evals_result = {}

# Entraînement avec early stopping
watchlist = [(dtrain, "train"), (dval, "eval")]
bst = xgb.train(
    params,
    dtrain,
    num_boost_round=1000, # les arbres sont ajoutés de manière itérative, maintenant si l'apprentissage n'évolue pas on ajoute plus d'arbre
    evals=watchlist,
    early_stopping_rounds=10,
    evals_result=evals_result,
    verbose_eval=True
)

# === Courbes d'apprentissage (loss, accuracy, f1) ===
train_loss = evals_result['train']['logloss']
val_loss = evals_result['eval']['logloss']

# On calcule manuellement accuracy et f1 à chaque étape
train_acc, val_acc, train_f1, val_f1 = [], [], [], []

for i in range(len(train_loss)):
    # Prédictions train et val à l'itération i
    y_train_pred = (bst.predict(dtrain, iteration_range=(0, i+1)) >= 0.5).astype(int)
    y_val_pred = (bst.predict(dval, iteration_range=(0, i+1)) >= 0.5).astype(int)

    # Accuracies
    train_acc.append(accuracy_score(y_train, y_train_pred))
    val_acc.append(accuracy_score(y_val, y_val_pred))

    # F1 scores
    train_f1.append(f1_score(y_train, y_train_pred))
    val_f1.append(f1_score(y_val, y_val_pred))


# Affichage des courbes 
epochs = range(1, len(train_loss) + 1)

plt.figure(figsize=(12, 5))

# --- Courbe de perte
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, label="Train Loss", marker="o")
plt.plot(epochs, val_loss, label="Validation Loss", marker="o")
plt.xlabel("Époque")
plt.ylabel("Perte")
plt.title("Courbe de perte")
plt.legend()
plt.grid(True)

# --- Courbes Accuracy et F1
plt.subplot(1, 2, 2)
plt.plot(epochs, train_acc, label="Train Acc", marker="o")
plt.plot(epochs, val_acc, label="Validation Acc", marker="o")
plt.plot(epochs, train_f1, label="Train F1", linestyle="--", color="green")
plt.plot(epochs, val_f1, label="Validation F1", linestyle="--", color="red")
plt.xlabel("Époque")
plt.ylabel("Score")
plt.title("Courbes Accuracy / F1")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()



# Prédiction sur les données de test
y_scores = bst.predict(dtest)
y_pred = (y_scores >= 0.5).astype(int)


os.makedirs("models", exist_ok=True)  # crée le dossier si absent

bst.save_model("models/sbert_xgb.json")  # ou best_modele_melange.json si tu veux
joblib.dump(le, "models/label_encoder.pkl")


# Sauvegarde du modèle 
bst.save_model("models/best_modele_melange.json")

# Sauvegarde du vectorizer 

joblib.dump(vectorizer, "models/vectorizer_melange.pkl")

# Rapport
print("=== Rapport de classification (TF-IDF + XGBoost) sur les données de test ===")
print(classification_report(y_test, y_pred, target_names=le.classes_))

# Matrice de confusion
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=le.classes_)
disp.plot(cmap="Blues")
plt.title("Matrice de confusion - TF-IDF + XGBoost sur les données de test")
plt.tight_layout()
plt.show()

# Courbe AUC-PR
precision, recall, _ = precision_recall_curve(y_test, y_scores)
auc_pr = average_precision_score(y_test, y_scores)

plt.figure(figsize=(7, 5))
plt.plot(recall, precision, label=f"AUC-PR = {auc_pr:.2f}", color="green")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Courbe Precision-Recall - TF-IDF + XGBoost sur les données de test")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# [0]	train-logloss:0.30855	eval-logloss:0.30865
# [1]	train-logloss:0.28729	eval-logloss:0.29015
# [2]	train-logloss:0.26967	eval-logloss:0.27470
# [3]	train-logloss:0.25564	eval-logloss:0.26322
# [4]	train-logloss:0.24774	eval-logloss:0.25649
# [5]	train-logloss:0.23637	eval-logloss:0.24586
# [6]	train-logloss:0.22648	eval-logloss:0.23793
# [7]	train-logloss:0.21807	eval-logloss:0.23008
# [8]	train-logloss:0.20948	eval-logloss:0.22359
# [9]	train-logloss:0.20216	eval-logloss:0.21875
# [10]	train-logloss:0.19502	eval-logloss:0.21330
# [11]	train-logloss:0.19025	eval-logloss:0.21024
# [12]	train-logloss:0.18475	eval-logloss:0.20739
# [13]	train-logloss:0.17961	eval-logloss:0.20328
# [14]	train-logloss:0.17486	eval-logloss:0.20013
# [15]	train-logloss:0.16966	eval-logloss:0.19637
# [16]	train-logloss:0.16516	eval-logloss:0.19391
# [17]	train-logloss:0.16122	eval-logloss:0.19084
# [18]	train-logloss:0.15704	eval-logloss:0.18814
# [19]	train-logloss:0.15277	eval-logloss:0.18549
# [20]	train-logloss:0.14877	eval-logloss:0.18305
# [21]	train-logloss:0.14520	eval-logloss:0.18080
# [22]	train-logloss:0.14259	eval-logloss:0.17898
# [23]	train-logloss:0.13921	eval-logloss:0.17652
# [24]	train-logloss:0.13610	eval-logloss:0.17423
# [25]	train-logloss:0.13325	eval-logloss:0.17297
# [26]	train-logloss:0.13019	eval-logloss:0.17122
# [27]	train-logloss:0.12732	eval-logloss:0.16941
# [28]	train-logloss:0.12473	eval-logloss:0.16765
# [29]	train-logloss:0.12202	eval-logloss:0.16585
# [30]	train-logloss:0.11924	eval-logloss:0.16351
# [31]	train-logloss:0.11657	eval-logloss:0.16191
# [32]	train-logloss:0.11437	eval-logloss:0.16094
# [33]	train-logloss:0.11232	eval-logloss:0.15955
# [34]	train-logloss:0.11043	eval-logloss:0.15875
# [35]	train-logloss:0.10817	eval-logloss:0.15782
# [36]	train-logloss:0.10623	eval-logloss:0.15628
# [37]	train-logloss:0.10409	eval-logloss:0.15497
# [38]	train-logloss:0.10242	eval-logloss:0.15404
# [39]	train-logloss:0.10068	eval-logloss:0.15273
# [40]	train-logloss:0.09922	eval-logloss:0.15185
# [41]	train-logloss:0.09749	eval-logloss:0.15004
# [42]	train-logloss:0.09568	eval-logloss:0.14977
# [43]	train-logloss:0.09412	eval-logloss:0.14933
# [44]	train-logloss:0.09251	eval-logloss:0.14879
# [45]	train-logloss:0.09105	eval-logloss:0.14878
# [46]	train-logloss:0.08981	eval-logloss:0.14707
# [47]	train-logloss:0.08838	eval-logloss:0.14617
# [48]	train-logloss:0.08693	eval-logloss:0.14543
# [49]	train-logloss:0.08579	eval-logloss:0.14455
# [50]	train-logloss:0.08453	eval-logloss:0.14398
# [51]	train-logloss:0.08324	eval-logloss:0.14291
# [52]	train-logloss:0.08215	eval-logloss:0.14257
# [53]	train-logloss:0.08101	eval-logloss:0.14214
# [54]	train-logloss:0.08015	eval-logloss:0.14165
# [55]	train-logloss:0.07933	eval-logloss:0.14040
# [56]	train-logloss:0.07809	eval-logloss:0.13913
# [57]	train-logloss:0.07691	eval-logloss:0.13888
# [58]	train-logloss:0.07564	eval-logloss:0.13867
# [59]	train-logloss:0.07473	eval-logloss:0.13779
# [60]	train-logloss:0.07373	eval-logloss:0.13733
# [61]	train-logloss:0.07287	eval-logloss:0.13661
# [62]	train-logloss:0.07185	eval-logloss:0.13656
# [63]	train-logloss:0.07073	eval-logloss:0.13598
# [64]	train-logloss:0.06982	eval-logloss:0.13578
# [65]	train-logloss:0.06891	eval-logloss:0.13520
# [66]	train-logloss:0.06799	eval-logloss:0.13484
# [67]	train-logloss:0.06693	eval-logloss:0.13430
# [68]	train-logloss:0.06626	eval-logloss:0.13382
# [69]	train-logloss:0.06538	eval-logloss:0.13306
# [70]	train-logloss:0.06450	eval-logloss:0.13293
# [71]	train-logloss:0.06373	eval-logloss:0.13258
# [72]	train-logloss:0.06283	eval-logloss:0.13224
# [73]	train-logloss:0.06175	eval-logloss:0.13220
# [74]	train-logloss:0.06078	eval-logloss:0.13159
# [75]	train-logloss:0.06016	eval-logloss:0.13139
# [76]	train-logloss:0.05956	eval-logloss:0.13120
# [77]	train-logloss:0.05878	eval-logloss:0.13034
# [78]	train-logloss:0.05820	eval-logloss:0.13059
# [79]	train-logloss:0.05737	eval-logloss:0.13060
# [80]	train-logloss:0.05676	eval-logloss:0.13059
# [81]	train-logloss:0.05633	eval-logloss:0.13003
# [82]	train-logloss:0.05562	eval-logloss:0.12948
# [83]	train-logloss:0.05506	eval-logloss:0.12944
# [84]	train-logloss:0.05460	eval-logloss:0.12908
# [85]	train-logloss:0.05398	eval-logloss:0.12867
# [86]	train-logloss:0.05340	eval-logloss:0.12825
# [87]	train-logloss:0.05294	eval-logloss:0.12771
# [88]	train-logloss:0.05228	eval-logloss:0.12772
# [89]	train-logloss:0.05166	eval-logloss:0.12733
# [90]	train-logloss:0.05121	eval-logloss:0.12737
# [91]	train-logloss:0.05061	eval-logloss:0.12755
# [92]	train-logloss:0.04987	eval-logloss:0.12710
# [93]	train-logloss:0.04927	eval-logloss:0.12676
# [94]	train-logloss:0.04890	eval-logloss:0.12621
# [95]	train-logloss:0.04835	eval-logloss:0.12563
# [96]	train-logloss:0.04789	eval-logloss:0.12571
# [97]	train-logloss:0.04751	eval-logloss:0.12542
# [98]	train-logloss:0.04703	eval-logloss:0.12539
# [99]	train-logloss:0.04661	eval-logloss:0.12530
# [100]	train-logloss:0.04608	eval-logloss:0.12476
# [101]	train-logloss:0.04572	eval-logloss:0.12414
# [102]	train-logloss:0.04523	eval-logloss:0.12394
# [103]	train-logloss:0.04476	eval-logloss:0.12398
# [104]	train-logloss:0.04444	eval-logloss:0.12382
# [105]	train-logloss:0.04402	eval-logloss:0.12380
# [106]	train-logloss:0.04365	eval-logloss:0.12376
# [107]	train-logloss:0.04313	eval-logloss:0.12337
# [108]	train-logloss:0.04273	eval-logloss:0.12318
# [109]	train-logloss:0.04241	eval-logloss:0.12297
# [110]	train-logloss:0.04213	eval-logloss:0.12256
# [111]	train-logloss:0.04172	eval-logloss:0.12266
# [112]	train-logloss:0.04137	eval-logloss:0.12237
# [113]	train-logloss:0.04099	eval-logloss:0.12244
# [114]	train-logloss:0.04047	eval-logloss:0.12264
# [115]	train-logloss:0.04019	eval-logloss:0.12255
# [116]	train-logloss:0.03984	eval-logloss:0.12246
# [117]	train-logloss:0.03957	eval-logloss:0.12238
# [118]	train-logloss:0.03917	eval-logloss:0.12247
# [119]	train-logloss:0.03878	eval-logloss:0.12268
# [120]	train-logloss:0.03847	eval-logloss:0.12251
# [121]	train-logloss:0.03817	eval-logloss:0.12216
# [122]	train-logloss:0.03782	eval-logloss:0.12234
# [123]	train-logloss:0.03752	eval-logloss:0.12197
# [124]	train-logloss:0.03718	eval-logloss:0.12180
# [125]	train-logloss:0.03675	eval-logloss:0.12195
# [126]	train-logloss:0.03634	eval-logloss:0.12189
# [127]	train-logloss:0.03601	eval-logloss:0.12187
# [128]	train-logloss:0.03578	eval-logloss:0.12164
# [129]	train-logloss:0.03544	eval-logloss:0.12169
# [130]	train-logloss:0.03513	eval-logloss:0.12164
# [131]	train-logloss:0.03482	eval-logloss:0.12187
# [132]	train-logloss:0.03452	eval-logloss:0.12177
# [133]	train-logloss:0.03415	eval-logloss:0.12163
# [134]	train-logloss:0.03395	eval-logloss:0.12129
# [135]	train-logloss:0.03375	eval-logloss:0.12122
# [136]	train-logloss:0.03353	eval-logloss:0.12145
# [137]	train-logloss:0.03325	eval-logloss:0.12154
# [138]	train-logloss:0.03301	eval-logloss:0.12161
# [139]	train-logloss:0.03271	eval-logloss:0.12166
# [140]	train-logloss:0.03253	eval-logloss:0.12161
# [141]	train-logloss:0.03228	eval-logloss:0.12146
# [142]	train-logloss:0.03202	eval-logloss:0.12170
# [143]	train-logloss:0.03167	eval-logloss:0.12167
# [144]	train-logloss:0.03144	eval-logloss:0.12171
# === Rapport de classification (TF-IDF + XGBoost) sur les données de test ===
#               precision    recall  f1-score   support
#
#          NVS       0.98      0.99      0.98       202
#           VS       0.90      0.78      0.84        23
#
#     accuracy                           0.97       225
#    macro avg       0.94      0.89      0.91       225
# weighted avg       0.97      0.97      0.97       225

# %% [markdown]
# ### Commentaire
#
# Les performances sont réduites, peut-être devons nous voir en cela une réduction du surapprentissage?
#
# Voyons maintenant les mots que ce modèle utilise pour donner VS à une classe

# %%
# Récupérer les scores d'importance des features (TF-IDF)
importance_scores = bst.get_score(importance_type='weight')  # ou 'gain' pour l'impact moyen sur la perte

# Map features index to their names
feature_names = vectorizer.get_feature_names_out()

# Convertir les clés de type 'f123' -> index entier
feature_importances = {
    feature_names[int(k[1:])]: v for k, v in importance_scores.items()
}

# Trier par importance décroissante
sorted_features = sorted(feature_importances.items(), key=lambda x: x[1], reverse=True)

# Afficher les 20 mots les plus importants
print("Top 20 mots les plus influents (poids) :")
for word, score in sorted_features[:20]:
    print(f"{word} : {score}")
# Out:
# Top 20 mots les plus influents (poids) :
# mysterious : 74.0
# mystery : 57.0
# said : 33.0
# also : 28.0
# may : 22.0
# pig : 21.0
# flu : 20.0
# case : 19.0
# wildlife : 19.0
# first : 18.0
# health : 18.0
# across : 17.0
# leaf : 17.0
# state : 17.0
# appears : 16.0
# million : 16.0
# agriculture : 15.0
# cause : 15.0
# forest : 15.0
# outbreak : 15.0

# %% [markdown]
# Essayons de tester notre modèle avec des phrases que nous avions définnies plus haut

# %%
## les phrases 
phrases_test = [
    "A mysterious disease was reported by the group and may be a new unknown illness.",
    "The pest risk is high and this could target a certain block, said the group."
]


## Nettoyons 

phrases_tokenisees = [nettoyer_texte(phrase) for phrase in phrases_test]

## Reformater les textes 
phrases_nettoyees = [" ".join(tokens) for tokens in phrases_tokenisees]


# Vectorisation (penser à sauvegarder le vectorizer qu'on pourra charger à ce niveau)
X_test_new = vectorizer.transform(phrases_nettoyees)

## Prédictions avec xgboost
dtest_new = xgb.DMatrix(X_test_new)
y_scores_new = bst.predict(dtest_new)


## Les résultats
for i, phrase in enumerate(phrases_test):
    print(f"\nTexte : {phrase}")
    print(f"Texte nettoyé : {phrases_nettoyees[i]}")
    print(f"-> Score VS : {y_scores_new[i]:.4f}")
    print(f"-> Score NVS : {1 - y_scores_new[i]:.4f}")
    classe_predite = "VS" if y_scores_new[i] >= 0.5 else "NVS"
    print(f"-> Classe prédite : {classe_predite}")
# Out:
# Texte : A mysterious disease was reported by the group and may be a new unknown illness.
# Texte nettoyé : mysterious disease reported group may new unknown illness
# -> Score VS : 0.9531
# -> Score NVS : 0.0469
# -> Classe prédite : VS
#
# Texte : The pest risk is high and this could target a certain block, said the group.
# Texte nettoyé : pest risk high could target certain block said group
# -> Score VS : 0.0698
# -> Score NVS : 0.9302
# -> Classe prédite : NVS

# %% [markdown]
# ### Commentaire
#
# Avec suppression des noms de maladie, nous constatons que le modèle n'arrive pas toujours à attribuer VS à la deuxième phrase malgré le fait que la phrase peut sembler utiliser les mots de la VS

# %% [markdown]
# ### Remplaçons la vectorisation TF-IDF avec SBERT
#
# Nous avons fait sur les données avec et sans nom de maladie, les meilleurs performances sont observées lorsqu'on garde les noms de maladie dans notre jeu de données (déjà elles ne sont pas en grande quantité ici)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    precision_recall_curve,
    average_precision_score,
    accuracy_score,
    f1_score,
)
import matplotlib.pyplot as plt
import numpy as np
import xgboost as xgb
import joblib
from sentence_transformers import SentenceTransformer
import os

# === 1. Données
X = data["text_clean"]
y = data["type_article"]

# Encodage binaire (NVS = 0, VS = 1)
le = LabelEncoder()
y_enc = le.fit_transform(y)

# === 2. Split train / temp
X_train_texts, X_temp_texts, y_train, y_temp = train_test_split(
    X, y_enc, test_size=0.3, stratify=y_enc, random_state=42
)

# === 3. Split temp → validation / test
X_val_texts, X_test_texts, y_val, y_test = train_test_split(
    X_temp_texts, y_temp, test_size=0.3, stratify=y_temp, random_state=42
)

# === 4. SBERT embeddings (remplace TF-IDF)
sbert_name = "all-MiniLM-L6-v2"
sbert = SentenceTransformer(sbert_name)

def embed(texts):
    # Retourne un np.array (n_samples, 384)
    return sbert.encode(
        texts.tolist() if hasattr(texts, "tolist") else texts,
        batch_size=64,
        convert_to_numpy=True,
        normalize_embeddings=False,   # mettre True si vous souhaitez L2-normaliser
        show_progress_bar=True,
    )

X_train_vec = embed(X_train_texts)
X_val_vec   = embed(X_val_texts)
X_test_vec  = embed(X_test_texts)

# === 5. XGBoost sur embeddings SBERT (avec early stopping)
# Gestion du déséquilibre éventuel
pos = (y_train == 1).sum()
neg = (y_train == 0).sum()
scale_pos_weight = neg / max(pos, 1)

dtrain = xgb.DMatrix(X_train_vec, label=y_train)
dval   = xgb.DMatrix(X_val_vec,   label=y_val)
dtest  = xgb.DMatrix(X_test_vec)

params = {
    "objective": "binary:logistic",
    "eval_metric": ["logloss", "aucpr"],  # on suit loss + AUC-PR
    "max_depth": 5,
    "eta": 0.05,
    "subsample": 0.8,
    "colsample_bytree": 0.8,
    "seed": 42,
    "scale_pos_weight": scale_pos_weight,  # utile si classes déséquilibrées
}

evals_result = {}
watchlist = [(dtrain, "train"), (dval, "eval")]
bst = xgb.train(
    params,
    dtrain,
    num_boost_round=1000,
    evals=watchlist,
    early_stopping_rounds=20,
    evals_result=evals_result,
    verbose_eval=True,
)

# === Courbes d'apprentissage (loss + acc/f1 par itération)
train_loss = evals_result["train"]["logloss"]
val_loss   = evals_result["eval"]["logloss"]

train_acc, val_acc, train_f1, val_f1 = [], [], [], []
for i in range(len(train_loss)):
    # Prédictions à l'itération i
    y_train_pred = (bst.predict(dtrain, iteration_range=(0, i+1)) >= 0.5).astype(int)
    y_val_pred   = (bst.predict(dval,   iteration_range=(0, i+1)) >= 0.5).astype(int)

    train_acc.append(accuracy_score(y_train, y_train_pred))
    val_acc.append(accuracy_score(y_val, y_val_pred))
    train_f1.append(f1_score(y_train, y_train_pred))
    val_f1.append(f1_score(y_val, y_val_pred))

epochs = range(1, len(train_loss) + 1)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, label="Train Loss", marker="o")
plt.plot(epochs, val_loss,   label="Validation Loss", marker="o")
plt.xlabel("Itération")
plt.ylabel("Perte")
plt.title("Courbe de perte (SBERT + XGBoost)")
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(epochs, train_acc, label="Train Acc", marker="o")
plt.plot(epochs, val_acc,   label="Val Acc", marker="o")
plt.plot(epochs, train_f1,  label="Train F1", linestyle="--")
plt.plot(epochs, val_f1,    label="Val F1", linestyle="--")
plt.xlabel("Itération")
plt.ylabel("Score")
plt.title("Accuracy / F1 par itération")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# === Test final
y_scores = bst.predict(dtest)                 # proba VS
y_pred   = (y_scores >= 0.5).astype(int)

print("=== Rapport (SBERT + XGBoost) - Test ===")
print(classification_report(y_test, y_pred, target_names=le.classes_))

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=le.classes_)
disp.plot(cmap="Blues")
plt.title("Matrice de confusion - SBERT + XGBoost (test)")
plt.tight_layout()
plt.show()

precision, recall, _ = precision_recall_curve(y_test, y_scores)
auc_pr = average_precision_score(y_test, y_scores)
plt.figure(figsize=(7,5))
plt.plot(recall, precision, label=f"AUC-PR = {auc_pr:.3f}")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall - SBERT + XGBoost (test)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# === Sauvegardes
os.makedirs("models", exist_ok=True)
bst.save_model("models/sbert_xgb.json")              # modèle XGBoost
joblib.dump(le, "models/label_encoder.pkl")          # label encoder
sbert.save("models/sbert_all-MiniLM-L6-v2")          # poids + config SBERT
joblib.dump({"sbert_name": sbert_name}, "models/sbert_meta.pkl")  # méta pour rechargement
# Out:
# C:\Users\stginrae.AFRIQUE-TP02\AppData\Roaming\Python\Python312\site-packages\huggingface_hub\file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Batches:   0%|          | 0/28 [00:00<?, ?it/s]
# Batches:   0%|          | 0/9 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# [0]	train-logloss:0.65475	train-aucpr:0.66145	eval-logloss:0.66032	eval-aucpr:0.41878
# [1]	train-logloss:0.62337	train-aucpr:0.80270	eval-logloss:0.63572	eval-aucpr:0.44251
# [2]	train-logloss:0.59246	train-aucpr:0.88027	eval-logloss:0.60994	eval-aucpr:0.47032
# [3]	train-logloss:0.56453	train-aucpr:0.93287	eval-logloss:0.58559	eval-aucpr:0.53885
# [4]	train-logloss:0.53755	train-aucpr:0.94331	eval-logloss:0.56266	eval-aucpr:0.59536
# [5]	train-logloss:0.51130	train-aucpr:0.96853	eval-logloss:0.53810	eval-aucpr:0.62541
# [6]	train-logloss:0.48820	train-aucpr:0.97424	eval-logloss:0.51880	eval-aucpr:0.64113
# [7]	train-logloss:0.46806	train-aucpr:0.98004	eval-logloss:0.50431	eval-aucpr:0.63086
# [8]	train-logloss:0.44807	train-aucpr:0.98313	eval-logloss:0.48669	eval-aucpr:0.66235
# [9]	train-logloss:0.42853	train-aucpr:0.98640	eval-logloss:0.47088	eval-aucpr:0.66033
# [10]	train-logloss:0.41137	train-aucpr:0.98656	eval-logloss:0.45584	eval-aucpr:0.67366
# [11]	train-logloss:0.39561	train-aucpr:0.98704	eval-logloss:0.44288	eval-aucpr:0.67467
# [12]	train-logloss:0.38030	train-aucpr:0.98897	eval-logloss:0.43210	eval-aucpr:0.66855
# [13]	train-logloss:0.36534	train-aucpr:0.99065	eval-logloss:0.42079	eval-aucpr:0.66518
# [14]	train-logloss:0.34942	train-aucpr:0.98989	eval-logloss:0.40865	eval-aucpr:0.66664
# [15]	train-logloss:0.33507	train-aucpr:0.99072	eval-logloss:0.39662	eval-aucpr:0.67582
# [16]	train-logloss:0.32316	train-aucpr:0.99155	eval-logloss:0.38652	eval-aucpr:0.67838
# [17]	train-logloss:0.31196	train-aucpr:0.99298	eval-logloss:0.37730	eval-aucpr:0.68032
# [18]	train-logloss:0.30108	train-aucpr:0.99263	eval-logloss:0.36904	eval-aucpr:0.67521
# [19]	train-logloss:0.29023	train-aucpr:0.99388	eval-logloss:0.35871	eval-aucpr:0.68137
# [20]	train-logloss:0.28024	train-aucpr:0.99406	eval-logloss:0.35041	eval-aucpr:0.68529
# [21]	train-logloss:0.27162	train-aucpr:0.99378	eval-logloss:0.34238	eval-aucpr:0.68929
# [22]	train-logloss:0.26213	train-aucpr:0.99296	eval-logloss:0.33284	eval-aucpr:0.70212
# [23]	train-logloss:0.25249	train-aucpr:0.99238	eval-logloss:0.32458	eval-aucpr:0.70744
# [24]	train-logloss:0.24406	train-aucpr:0.99195	eval-logloss:0.31707	eval-aucpr:0.70899
# [25]	train-logloss:0.23570	train-aucpr:0.99252	eval-logloss:0.30922	eval-aucpr:0.71111
# [26]	train-logloss:0.22805	train-aucpr:0.99281	eval-logloss:0.30269	eval-aucpr:0.71123
# [27]	train-logloss:0.22026	train-aucpr:0.99275	eval-logloss:0.29551	eval-aucpr:0.71553
# [28]	train-logloss:0.21307	train-aucpr:0.99398	eval-logloss:0.28978	eval-aucpr:0.71426
# [29]	train-logloss:0.20655	train-aucpr:0.99476	eval-logloss:0.28484	eval-aucpr:0.71311
# [30]	train-logloss:0.19996	train-aucpr:0.99382	eval-logloss:0.27820	eval-aucpr:0.72027
# [31]	train-logloss:0.19419	train-aucpr:0.99494	eval-logloss:0.27400	eval-aucpr:0.71785
# [32]	train-logloss:0.18766	train-aucpr:0.99473	eval-logloss:0.27002	eval-aucpr:0.71069
# [33]	train-logloss:0.18211	train-aucpr:0.99456	eval-logloss:0.26519	eval-aucpr:0.71358
# [34]	train-logloss:0.17648	train-aucpr:0.99571	eval-logloss:0.25968	eval-aucpr:0.71703
# [35]	train-logloss:0.17261	train-aucpr:0.99600	eval-logloss:0.25639	eval-aucpr:0.71567
# [36]	train-logloss:0.16761	train-aucpr:0.99578	eval-logloss:0.25269	eval-aucpr:0.72043
# [37]	train-logloss:0.16220	train-aucpr:0.99586	eval-logloss:0.24871	eval-aucpr:0.71978
# [38]	train-logloss:0.15784	train-aucpr:0.99640	eval-logloss:0.24573	eval-aucpr:0.71780
# [39]	train-logloss:0.15297	train-aucpr:0.99712	eval-logloss:0.24128	eval-aucpr:0.71841
# [40]	train-logloss:0.14934	train-aucpr:0.99701	eval-logloss:0.23849	eval-aucpr:0.71755
# [41]	train-logloss:0.14477	train-aucpr:0.99730	eval-logloss:0.23468	eval-aucpr:0.71722
# [42]	train-logloss:0.14084	train-aucpr:0.99732	eval-logloss:0.23192	eval-aucpr:0.71677
# [43]	train-logloss:0.13651	train-aucpr:0.99753	eval-logloss:0.22815	eval-aucpr:0.71678
# [44]	train-logloss:0.13366	train-aucpr:0.99735	eval-logloss:0.22574	eval-aucpr:0.72185
# [45]	train-logloss:0.13011	train-aucpr:0.99757	eval-logloss:0.22239	eval-aucpr:0.72382
# [46]	train-logloss:0.12609	train-aucpr:0.99785	eval-logloss:0.21904	eval-aucpr:0.72578
# [47]	train-logloss:0.12285	train-aucpr:0.99795	eval-logloss:0.21708	eval-aucpr:0.72393
# [48]	train-logloss:0.11949	train-aucpr:0.99799	eval-logloss:0.21462	eval-aucpr:0.72381
# [49]	train-logloss:0.11699	train-aucpr:0.99833	eval-logloss:0.21306	eval-aucpr:0.72443
# [50]	train-logloss:0.11335	train-aucpr:0.99863	eval-logloss:0.20922	eval-aucpr:0.72809
# [51]	train-logloss:0.11038	train-aucpr:0.99883	eval-logloss:0.20687	eval-aucpr:0.72823
# [52]	train-logloss:0.10711	train-aucpr:0.99895	eval-logloss:0.20446	eval-aucpr:0.72982
# [53]	train-logloss:0.10423	train-aucpr:0.99909	eval-logloss:0.20205	eval-aucpr:0.73085
# [54]	train-logloss:0.10145	train-aucpr:0.99923	eval-logloss:0.19994	eval-aucpr:0.73119
# [55]	train-logloss:0.09925	train-aucpr:0.99927	eval-logloss:0.19846	eval-aucpr:0.72982
# [56]	train-logloss:0.09663	train-aucpr:0.99946	eval-logloss:0.19589	eval-aucpr:0.73681
# [57]	train-logloss:0.09437	train-aucpr:0.99940	eval-logloss:0.19382	eval-aucpr:0.73577
# [58]	train-logloss:0.09196	train-aucpr:0.99940	eval-logloss:0.19189	eval-aucpr:0.74010
# [59]	train-logloss:0.09005	train-aucpr:0.99940	eval-logloss:0.18957	eval-aucpr:0.74256
# [60]	train-logloss:0.08745	train-aucpr:0.99954	eval-logloss:0.18803	eval-aucpr:0.74142
# [61]	train-logloss:0.08558	train-aucpr:0.99964	eval-logloss:0.18617	eval-aucpr:0.74426
# [62]	train-logloss:0.08367	train-aucpr:0.99967	eval-logloss:0.18511	eval-aucpr:0.74177
# [63]	train-logloss:0.08169	train-aucpr:0.99967	eval-logloss:0.18362	eval-aucpr:0.74156
# [64]	train-logloss:0.08011	train-aucpr:0.99977	eval-logloss:0.18223	eval-aucpr:0.74168
# [65]	train-logloss:0.07829	train-aucpr:0.99981	eval-logloss:0.18108	eval-aucpr:0.74270
# [66]	train-logloss:0.07665	train-aucpr:0.99984	eval-logloss:0.17985	eval-aucpr:0.74339
# [67]	train-logloss:0.07489	train-aucpr:0.99981	eval-logloss:0.17928	eval-aucpr:0.74043
# [68]	train-logloss:0.07325	train-aucpr:0.99984	eval-logloss:0.17814	eval-aucpr:0.74261
# [69]	train-logloss:0.07190	train-aucpr:0.99984	eval-logloss:0.17733	eval-aucpr:0.74219
# [70]	train-logloss:0.07084	train-aucpr:0.99984	eval-logloss:0.17631	eval-aucpr:0.74173
# [71]	train-logloss:0.07016	train-aucpr:0.99984	eval-logloss:0.17595	eval-aucpr:0.74053
# [72]	train-logloss:0.06863	train-aucpr:0.99984	eval-logloss:0.17501	eval-aucpr:0.74045
# [73]	train-logloss:0.06756	train-aucpr:0.99984	eval-logloss:0.17388	eval-aucpr:0.74391
# [74]	train-logloss:0.06592	train-aucpr:0.99984	eval-logloss:0.17286	eval-aucpr:0.74112
# [75]	train-logloss:0.06432	train-aucpr:0.99984	eval-logloss:0.17204	eval-aucpr:0.74208
# [76]	train-logloss:0.06291	train-aucpr:0.99984	eval-logloss:0.17099	eval-aucpr:0.74002
# [77]	train-logloss:0.06133	train-aucpr:0.99984	eval-logloss:0.16996	eval-aucpr:0.74271
# [78]	train-logloss:0.05993	train-aucpr:0.99984	eval-logloss:0.16942	eval-aucpr:0.74406
# [79]	train-logloss:0.05902	train-aucpr:0.99987	eval-logloss:0.16908	eval-aucpr:0.74400
# [80]	train-logloss:0.05772	train-aucpr:0.99990	eval-logloss:0.16865	eval-aucpr:0.74452
# [81]	train-logloss:0.05679	train-aucpr:0.99987	eval-logloss:0.16829	eval-aucpr:0.74509
# [82]	train-logloss:0.05585	train-aucpr:0.99987	eval-logloss:0.16774	eval-aucpr:0.74356
# [83]	train-logloss:0.05445	train-aucpr:0.99990	eval-logloss:0.16740	eval-aucpr:0.74509
# [84]	train-logloss:0.05350	train-aucpr:0.99990	eval-logloss:0.16700	eval-aucpr:0.74275
# [85]	train-logloss:0.05197	train-aucpr:0.99987	eval-logloss:0.16613	eval-aucpr:0.74563
# [86]	train-logloss:0.05068	train-aucpr:0.99990	eval-logloss:0.16504	eval-aucpr:0.74727
# [87]	train-logloss:0.04936	train-aucpr:0.99990	eval-logloss:0.16479	eval-aucpr:0.74561
# [88]	train-logloss:0.04847	train-aucpr:0.99990	eval-logloss:0.16413	eval-aucpr:0.74800
# [89]	train-logloss:0.04735	train-aucpr:0.99990	eval-logloss:0.16331	eval-aucpr:0.74696
# [90]	train-logloss:0.04634	train-aucpr:0.99990	eval-logloss:0.16267	eval-aucpr:0.75014
# [91]	train-logloss:0.04589	train-aucpr:0.99990	eval-logloss:0.16216	eval-aucpr:0.75081
# [92]	train-logloss:0.04511	train-aucpr:0.99990	eval-logloss:0.16192	eval-aucpr:0.75146
# [93]	train-logloss:0.04444	train-aucpr:0.99990	eval-logloss:0.16155	eval-aucpr:0.75278
# [94]	train-logloss:0.04345	train-aucpr:0.99990	eval-logloss:0.16100	eval-aucpr:0.75149
# [95]	train-logloss:0.04283	train-aucpr:0.99990	eval-logloss:0.16086	eval-aucpr:0.75016
# [96]	train-logloss:0.04192	train-aucpr:0.99990	eval-logloss:0.16031	eval-aucpr:0.74973
# [97]	train-logloss:0.04110	train-aucpr:0.99993	eval-logloss:0.16029	eval-aucpr:0.74957
# [98]	train-logloss:0.04021	train-aucpr:0.99993	eval-logloss:0.16015	eval-aucpr:0.74909
# [99]	train-logloss:0.03956	train-aucpr:0.99993	eval-logloss:0.15983	eval-aucpr:0.75085
# [100]	train-logloss:0.03875	train-aucpr:0.99993	eval-logloss:0.15952	eval-aucpr:0.74939
# [101]	train-logloss:0.03817	train-aucpr:0.99993	eval-logloss:0.15935	eval-aucpr:0.74927
# [102]	train-logloss:0.03751	train-aucpr:0.99993	eval-logloss:0.15906	eval-aucpr:0.74997
# [103]	train-logloss:0.03694	train-aucpr:0.99993	eval-logloss:0.15873	eval-aucpr:0.75062
# [104]	train-logloss:0.03638	train-aucpr:0.99993	eval-logloss:0.15879	eval-aucpr:0.75311
# [105]	train-logloss:0.03574	train-aucpr:0.99993	eval-logloss:0.15864	eval-aucpr:0.75300
# [106]	train-logloss:0.03496	train-aucpr:0.99993	eval-logloss:0.15775	eval-aucpr:0.75661
# [107]	train-logloss:0.03458	train-aucpr:0.99993	eval-logloss:0.15769	eval-aucpr:0.75722
# [108]	train-logloss:0.03396	train-aucpr:0.99993	eval-logloss:0.15737	eval-aucpr:0.75954
# [109]	train-logloss:0.03328	train-aucpr:0.99993	eval-logloss:0.15772	eval-aucpr:0.75778
# [110]	train-logloss:0.03269	train-aucpr:0.99993	eval-logloss:0.15702	eval-aucpr:0.75745
# [111]	train-logloss:0.03212	train-aucpr:0.99993	eval-logloss:0.15699	eval-aucpr:0.75587
# [112]	train-logloss:0.03169	train-aucpr:0.99993	eval-logloss:0.15682	eval-aucpr:0.75666
# [113]	train-logloss:0.03098	train-aucpr:0.99993	eval-logloss:0.15614	eval-aucpr:0.75776
# [114]	train-logloss:0.03061	train-aucpr:0.99993	eval-logloss:0.15619	eval-aucpr:0.75743
# [115]	train-logloss:0.03029	train-aucpr:0.99993	eval-logloss:0.15601	eval-aucpr:0.75791
# [116]	train-logloss:0.02978	train-aucpr:0.99993	eval-logloss:0.15604	eval-aucpr:0.75874
# [117]	train-logloss:0.02947	train-aucpr:0.99993	eval-logloss:0.15557	eval-aucpr:0.75970
# [118]	train-logloss:0.02900	train-aucpr:0.99993	eval-logloss:0.15520	eval-aucpr:0.76049
# [119]	train-logloss:0.02842	train-aucpr:0.99993	eval-logloss:0.15552	eval-aucpr:0.75955
# [120]	train-logloss:0.02817	train-aucpr:0.99993	eval-logloss:0.15530	eval-aucpr:0.76100
# [121]	train-logloss:0.02785	train-aucpr:0.99993	eval-logloss:0.15558	eval-aucpr:0.75811
# [122]	train-logloss:0.02740	train-aucpr:0.99993	eval-logloss:0.15560	eval-aucpr:0.75934
# [123]	train-logloss:0.02709	train-aucpr:0.99993	eval-logloss:0.15537	eval-aucpr:0.75871
# [124]	train-logloss:0.02669	train-aucpr:0.99993	eval-logloss:0.15487	eval-aucpr:0.76093
# [125]	train-logloss:0.02627	train-aucpr:0.99993	eval-logloss:0.15433	eval-aucpr:0.76272
# [126]	train-logloss:0.02589	train-aucpr:0.99993	eval-logloss:0.15448	eval-aucpr:0.76227
# [127]	train-logloss:0.02554	train-aucpr:0.99993	eval-logloss:0.15405	eval-aucpr:0.76058
# [128]	train-logloss:0.02514	train-aucpr:0.99993	eval-logloss:0.15371	eval-aucpr:0.76477
# [129]	train-logloss:0.02462	train-aucpr:0.99993	eval-logloss:0.15364	eval-aucpr:0.76420
# [130]	train-logloss:0.02436	train-aucpr:0.99993	eval-logloss:0.15349	eval-aucpr:0.76411
# [131]	train-logloss:0.02408	train-aucpr:0.99993	eval-logloss:0.15373	eval-aucpr:0.76474
# [132]	train-logloss:0.02390	train-aucpr:0.99993	eval-logloss:0.15367	eval-aucpr:0.76345
# [133]	train-logloss:0.02345	train-aucpr:0.99993	eval-logloss:0.15368	eval-aucpr:0.76424
# [134]	train-logloss:0.02305	train-aucpr:0.99993	eval-logloss:0.15399	eval-aucpr:0.76265
# [135]	train-logloss:0.02280	train-aucpr:0.99993	eval-logloss:0.15408	eval-aucpr:0.76221
# [136]	train-logloss:0.02244	train-aucpr:0.99993	eval-logloss:0.15346	eval-aucpr:0.76553
# [137]	train-logloss:0.02205	train-aucpr:0.99993	eval-logloss:0.15315	eval-aucpr:0.76698
# [138]	train-logloss:0.02177	train-aucpr:0.99993	eval-logloss:0.15297	eval-aucpr:0.76828
# [139]	train-logloss:0.02144	train-aucpr:0.99993	eval-logloss:0.15222	eval-aucpr:0.76919
# [140]	train-logloss:0.02109	train-aucpr:0.99993	eval-logloss:0.15226	eval-aucpr:0.76813
# [141]	train-logloss:0.02083	train-aucpr:0.99993	eval-logloss:0.15252	eval-aucpr:0.76855
# [142]	train-logloss:0.02069	train-aucpr:0.99993	eval-logloss:0.15222	eval-aucpr:0.76876
# [143]	train-logloss:0.02036	train-aucpr:0.99993	eval-logloss:0.15257	eval-aucpr:0.76801
# [144]	train-logloss:0.02002	train-aucpr:0.99993	eval-logloss:0.15260	eval-aucpr:0.76928
# [145]	train-logloss:0.01974	train-aucpr:0.99993	eval-logloss:0.15193	eval-aucpr:0.76924
# [146]	train-logloss:0.01949	train-aucpr:0.99993	eval-logloss:0.15198	eval-aucpr:0.76911
# [147]	train-logloss:0.01917	train-aucpr:0.99993	eval-logloss:0.15178	eval-aucpr:0.76994
# [148]	train-logloss:0.01899	train-aucpr:0.99993	eval-logloss:0.15155	eval-aucpr:0.77089
# [149]	train-logloss:0.01874	train-aucpr:0.99993	eval-logloss:0.15172	eval-aucpr:0.76890
# [150]	train-logloss:0.01861	train-aucpr:0.99993	eval-logloss:0.15194	eval-aucpr:0.76911
# [151]	train-logloss:0.01842	train-aucpr:0.99993	eval-logloss:0.15150	eval-aucpr:0.77155
# [152]	train-logloss:0.01826	train-aucpr:0.99993	eval-logloss:0.15134	eval-aucpr:0.77167
# [153]	train-logloss:0.01792	train-aucpr:0.99993	eval-logloss:0.15106	eval-aucpr:0.77233
# [154]	train-logloss:0.01774	train-aucpr:0.99993	eval-logloss:0.15112	eval-aucpr:0.77305
# [155]	train-logloss:0.01741	train-aucpr:0.99993	eval-logloss:0.15076	eval-aucpr:0.77397
# [156]	train-logloss:0.01721	train-aucpr:0.99993	eval-logloss:0.15078	eval-aucpr:0.77466
# [157]	train-logloss:0.01701	train-aucpr:0.99993	eval-logloss:0.15072	eval-aucpr:0.77361
# [158]	train-logloss:0.01680	train-aucpr:0.99993	eval-logloss:0.15041	eval-aucpr:0.77482
# [159]	train-logloss:0.01658	train-aucpr:0.99993	eval-logloss:0.15060	eval-aucpr:0.77402
# [160]	train-logloss:0.01640	train-aucpr:0.99993	eval-logloss:0.15065	eval-aucpr:0.77439
# [161]	train-logloss:0.01619	train-aucpr:0.99993	eval-logloss:0.15056	eval-aucpr:0.77522
# [162]	train-logloss:0.01596	train-aucpr:0.99993	eval-logloss:0.15077	eval-aucpr:0.77558
# [163]	train-logloss:0.01585	train-aucpr:0.99993	eval-logloss:0.15063	eval-aucpr:0.77548
# [164]	train-logloss:0.01567	train-aucpr:0.99993	eval-logloss:0.15065	eval-aucpr:0.77638
# [165]	train-logloss:0.01552	train-aucpr:0.99993	eval-logloss:0.15043	eval-aucpr:0.77551
# [166]	train-logloss:0.01531	train-aucpr:0.99993	eval-logloss:0.15061	eval-aucpr:0.77656
# [167]	train-logloss:0.01513	train-aucpr:0.99993	eval-logloss:0.15095	eval-aucpr:0.77748
# [168]	train-logloss:0.01499	train-aucpr:0.99993	eval-logloss:0.15108	eval-aucpr:0.77814
# [169]	train-logloss:0.01476	train-aucpr:0.99993	eval-logloss:0.15133	eval-aucpr:0.77677
# [170]	train-logloss:0.01457	train-aucpr:0.99993	eval-logloss:0.15124	eval-aucpr:0.77759
# [171]	train-logloss:0.01440	train-aucpr:0.99993	eval-logloss:0.15100	eval-aucpr:0.77835
# [172]	train-logloss:0.01427	train-aucpr:0.99993	eval-logloss:0.15100	eval-aucpr:0.77747
# [173]	train-logloss:0.01414	train-aucpr:0.99993	eval-logloss:0.15090	eval-aucpr:0.77910
# [174]	train-logloss:0.01393	train-aucpr:0.99993	eval-logloss:0.15032	eval-aucpr:0.77915
# [175]	train-logloss:0.01377	train-aucpr:0.99993	eval-logloss:0.15042	eval-aucpr:0.77919
# [176]	train-logloss:0.01353	train-aucpr:0.99993	eval-logloss:0.15059	eval-aucpr:0.78050
# [177]	train-logloss:0.01345	train-aucpr:0.99993	eval-logloss:0.15055	eval-aucpr:0.78145
# [178]	train-logloss:0.01332	train-aucpr:0.99993	eval-logloss:0.15085	eval-aucpr:0.78161
# [179]	train-logloss:0.01318	train-aucpr:0.99993	eval-logloss:0.15082	eval-aucpr:0.78299
# [180]	train-logloss:0.01309	train-aucpr:0.99993	eval-logloss:0.15089	eval-aucpr:0.78244
# [181]	train-logloss:0.01301	train-aucpr:0.99993	eval-logloss:0.15070	eval-aucpr:0.78235
# [182]	train-logloss:0.01292	train-aucpr:0.99993	eval-logloss:0.15078	eval-aucpr:0.78102
# [183]	train-logloss:0.01282	train-aucpr:0.99993	eval-logloss:0.15029	eval-aucpr:0.78316
# [184]	train-logloss:0.01275	train-aucpr:0.99993	eval-logloss:0.15059	eval-aucpr:0.78335
# [185]	train-logloss:0.01266	train-aucpr:0.99993	eval-logloss:0.15051	eval-aucpr:0.78284
# [186]	train-logloss:0.01253	train-aucpr:0.99993	eval-logloss:0.15057	eval-aucpr:0.78392
# [187]	train-logloss:0.01244	train-aucpr:0.99993	eval-logloss:0.15028	eval-aucpr:0.78366
# [188]	train-logloss:0.01235	train-aucpr:0.99993	eval-logloss:0.15067	eval-aucpr:0.78317
# [189]	train-logloss:0.01226	train-aucpr:0.99993	eval-logloss:0.15066	eval-aucpr:0.78576
# [190]	train-logloss:0.01213	train-aucpr:0.99993	eval-logloss:0.15091	eval-aucpr:0.78502
# [191]	train-logloss:0.01195	train-aucpr:0.99993	eval-logloss:0.15097	eval-aucpr:0.78519
# [192]	train-logloss:0.01176	train-aucpr:0.99993	eval-logloss:0.15095	eval-aucpr:0.78449
# [193]	train-logloss:0.01171	train-aucpr:0.99993	eval-logloss:0.15129	eval-aucpr:0.78387
# [194]	train-logloss:0.01160	train-aucpr:0.99993	eval-logloss:0.15184	eval-aucpr:0.78336
# [195]	train-logloss:0.01156	train-aucpr:0.99993	eval-logloss:0.15219	eval-aucpr:0.78323
# [196]	train-logloss:0.01146	train-aucpr:0.99993	eval-logloss:0.15221	eval-aucpr:0.78319
# [197]	train-logloss:0.01141	train-aucpr:0.99993	eval-logloss:0.15230	eval-aucpr:0.78375
# [198]	train-logloss:0.01121	train-aucpr:0.99993	eval-logloss:0.15195	eval-aucpr:0.78473
# [199]	train-logloss:0.01112	train-aucpr:0.99993	eval-logloss:0.15176	eval-aucpr:0.78467
# [200]	train-logloss:0.01094	train-aucpr:0.99993	eval-logloss:0.15127	eval-aucpr:0.78734
# [201]	train-logloss:0.01084	train-aucpr:0.99993	eval-logloss:0.15102	eval-aucpr:0.78740
# [202]	train-logloss:0.01074	train-aucpr:0.99993	eval-logloss:0.15117	eval-aucpr:0.78712
# [203]	train-logloss:0.01069	train-aucpr:0.99993	eval-logloss:0.15130	eval-aucpr:0.78711
# [204]	train-logloss:0.01060	train-aucpr:0.99993	eval-logloss:0.15131	eval-aucpr:0.78743
# [205]	train-logloss:0.01053	train-aucpr:0.99993	eval-logloss:0.15109	eval-aucpr:0.78758
# [206]	train-logloss:0.01034	train-aucpr:0.99993	eval-logloss:0.15078	eval-aucpr:0.78798
# [207]	train-logloss:0.01026	train-aucpr:0.99993	eval-logloss:0.15107	eval-aucpr:0.78798
# [208]	train-logloss:0.01009	train-aucpr:0.99993	eval-logloss:0.15133	eval-aucpr:0.78774
# [209]	train-logloss:0.01008	train-aucpr:0.99993	eval-logloss:0.15131	eval-aucpr:0.78764
# [210]	train-logloss:0.00992	train-aucpr:0.99993	eval-logloss:0.15150	eval-aucpr:0.78767
# [211]	train-logloss:0.00984	train-aucpr:0.99993	eval-logloss:0.15141	eval-aucpr:0.78772
# [212]	train-logloss:0.00979	train-aucpr:0.99993	eval-logloss:0.15144	eval-aucpr:0.78718
# [213]	train-logloss:0.00976	train-aucpr:0.99993	eval-logloss:0.15115	eval-aucpr:0.78905
# [214]	train-logloss:0.00961	train-aucpr:0.99993	eval-logloss:0.15097	eval-aucpr:0.79140
# [215]	train-logloss:0.00946	train-aucpr:0.99993	eval-logloss:0.15082	eval-aucpr:0.79068
# [216]	train-logloss:0.00944	train-aucpr:0.99993	eval-logloss:0.15051	eval-aucpr:0.79142
# [217]	train-logloss:0.00941	train-aucpr:0.99993	eval-logloss:0.15014	eval-aucpr:0.79266
# [218]	train-logloss:0.00937	train-aucpr:0.99993	eval-logloss:0.14994	eval-aucpr:0.79316
# [219]	train-logloss:0.00934	train-aucpr:0.99993	eval-logloss:0.15004	eval-aucpr:0.79507
# [220]	train-logloss:0.00922	train-aucpr:0.99993	eval-logloss:0.14975	eval-aucpr:0.79589
# [221]	train-logloss:0.00909	train-aucpr:0.99993	eval-logloss:0.14948	eval-aucpr:0.79535
# [222]	train-logloss:0.00908	train-aucpr:0.99993	eval-logloss:0.14956	eval-aucpr:0.79477
# [223]	train-logloss:0.00897	train-aucpr:0.99993	eval-logloss:0.14940	eval-aucpr:0.79552
# [224]	train-logloss:0.00895	train-aucpr:0.99993	eval-logloss:0.14931	eval-aucpr:0.79537
# [225]	train-logloss:0.00881	train-aucpr:0.99993	eval-logloss:0.14961	eval-aucpr:0.79597
# [226]	train-logloss:0.00877	train-aucpr:0.99993	eval-logloss:0.14957	eval-aucpr:0.79499
# [227]	train-logloss:0.00875	train-aucpr:0.99993	eval-logloss:0.14940	eval-aucpr:0.79553
# [228]	train-logloss:0.00875	train-aucpr:0.99993	eval-logloss:0.14956	eval-aucpr:0.79594
# [229]	train-logloss:0.00874	train-aucpr:0.99993	eval-logloss:0.14952	eval-aucpr:0.79550
# [230]	train-logloss:0.00872	train-aucpr:0.99993	eval-logloss:0.14967	eval-aucpr:0.79587
# [231]	train-logloss:0.00868	train-aucpr:0.99993	eval-logloss:0.14991	eval-aucpr:0.79561
# [232]	train-logloss:0.00868	train-aucpr:0.99993	eval-logloss:0.15002	eval-aucpr:0.79633
# [233]	train-logloss:0.00863	train-aucpr:0.99993	eval-logloss:0.15010	eval-aucpr:0.79720
# [234]	train-logloss:0.00858	train-aucpr:0.99993	eval-logloss:0.14983	eval-aucpr:0.79732
# [235]	train-logloss:0.00855	train-aucpr:0.99993	eval-logloss:0.14967	eval-aucpr:0.79793
# [236]	train-logloss:0.00855	train-aucpr:0.99993	eval-logloss:0.14988	eval-aucpr:0.79734
# [237]	train-logloss:0.00852	train-aucpr:0.99993	eval-logloss:0.15002	eval-aucpr:0.79883
# [238]	train-logloss:0.00847	train-aucpr:0.99993	eval-logloss:0.15021	eval-aucpr:0.79872
# [239]	train-logloss:0.00832	train-aucpr:0.99993	eval-logloss:0.15058	eval-aucpr:0.79817
# [240]	train-logloss:0.00829	train-aucpr:0.99993	eval-logloss:0.15049	eval-aucpr:0.79811
# [241]	train-logloss:0.00828	train-aucpr:0.99993	eval-logloss:0.15032	eval-aucpr:0.79855
# [242]	train-logloss:0.00830	train-aucpr:0.99993	eval-logloss:0.15038	eval-aucpr:0.79949
# [243]	train-logloss:0.00827	train-aucpr:0.99993	eval-logloss:0.15031	eval-aucpr:0.79914
# [244]	train-logloss:0.00824	train-aucpr:0.99993	eval-logloss:0.15054	eval-aucpr:0.80045
# [245]	train-logloss:0.00821	train-aucpr:0.99993	eval-logloss:0.15045	eval-aucpr:0.80046
# [246]	train-logloss:0.00820	train-aucpr:0.99993	eval-logloss:0.15015	eval-aucpr:0.79930
# [247]	train-logloss:0.00816	train-aucpr:0.99993	eval-logloss:0.15015	eval-aucpr:0.80025
# [248]	train-logloss:0.00806	train-aucpr:0.99993	eval-logloss:0.15008	eval-aucpr:0.80141
# [249]	train-logloss:0.00801	train-aucpr:0.99993	eval-logloss:0.15038	eval-aucpr:0.80002
# [250]	train-logloss:0.00788	train-aucpr:0.99993	eval-logloss:0.15049	eval-aucpr:0.79933
# [251]	train-logloss:0.00786	train-aucpr:0.99993	eval-logloss:0.15043	eval-aucpr:0.79975
# [252]	train-logloss:0.00773	train-aucpr:0.99993	eval-logloss:0.15069	eval-aucpr:0.80007
# [253]	train-logloss:0.00769	train-aucpr:0.99993	eval-logloss:0.15084	eval-aucpr:0.79966
# [254]	train-logloss:0.00759	train-aucpr:0.99993	eval-logloss:0.15104	eval-aucpr:0.79965
# [255]	train-logloss:0.00757	train-aucpr:0.99993	eval-logloss:0.15086	eval-aucpr:0.80056
# [256]	train-logloss:0.00757	train-aucpr:0.99993	eval-logloss:0.15093	eval-aucpr:0.79947
# [257]	train-logloss:0.00747	train-aucpr:0.99993	eval-logloss:0.15132	eval-aucpr:0.79869
# [258]	train-logloss:0.00744	train-aucpr:0.99993	eval-logloss:0.15145	eval-aucpr:0.79925
# [259]	train-logloss:0.00743	train-aucpr:0.99993	eval-logloss:0.15164	eval-aucpr:0.79895
# [260]	train-logloss:0.00743	train-aucpr:0.99993	eval-logloss:0.15198	eval-aucpr:0.79962
# [261]	train-logloss:0.00741	train-aucpr:0.99993	eval-logloss:0.15225	eval-aucpr:0.79803
# [262]	train-logloss:0.00734	train-aucpr:0.99993	eval-logloss:0.15224	eval-aucpr:0.79827
# [263]	train-logloss:0.00734	train-aucpr:0.99993	eval-logloss:0.15235	eval-aucpr:0.79711
# [264]	train-logloss:0.00733	train-aucpr:0.99993	eval-logloss:0.15254	eval-aucpr:0.79739
# [265]	train-logloss:0.00731	train-aucpr:0.99993	eval-logloss:0.15267	eval-aucpr:0.79671
# [266]	train-logloss:0.00731	train-aucpr:0.99993	eval-logloss:0.15250	eval-aucpr:0.79804
# [267]	train-logloss:0.00730	train-aucpr:0.99993	eval-logloss:0.15252	eval-aucpr:0.79851
# [268]	train-logloss:0.00727	train-aucpr:0.99993	eval-logloss:0.15245	eval-aucpr:0.79859
# === Rapport (SBERT + XGBoost) - Test ===
#               precision    recall  f1-score   support
#
#          NVS       0.95      0.99      0.97       202
#           VS       0.86      0.52      0.65        23
#
#     accuracy                           0.94       225
#    macro avg       0.90      0.76      0.81       225
# weighted avg       0.94      0.94      0.94       225
# ['models/sbert_meta.pkl']

# %%
import joblib
import xgboost as xgb
from sentence_transformers import SentenceTransformer
import numpy as np

# --- 1) Charger les modèles entraînés ---
# Chemins à adapter si besoin
bst = xgb.Booster()
bst.load_model("models/sbert_xgb.json")              # modèle XGBoost sauvegardé
sbert = SentenceTransformer("models/sbert_all-MiniLM-L6-v2")  # SBERT sauvegardé
le = joblib.load("models/label_encoder.pkl")         # optionnel (pour les noms de classes)

# --- 2) Phrases à tester ---
phrases_test = [
    "A mysterious disease was reported by the group and may be a new unknown illness.",
    "The pest risk is high and this could target a certain block, said the group."
]

# --- 3) Nettoyage identique à l'entraînement ---
# ta fonction doit être la même que celle utilisée au train :
# elle renvoie soit une liste de tokens, soit un texte propre
def preprocess_for_inference(texts):
    cleaned = []
    for p in texts:
        tokens = nettoyer_texte(p)     # ta fonction existante
        if isinstance(tokens, list):
            cleaned.append(" ".join(tokens))
        else:
            cleaned.append(tokens)
    return cleaned

phrases_nettoyees = preprocess_for_inference(phrases_test)

# --- 4) Embeddings SBERT (mêmes options qu’au train) ---
X_test_new = sbert.encode(
    phrases_nettoyees,
    batch_size=64,
    convert_to_numpy=True,
    normalize_embeddings=False,   # gardez la même valeur qu’au training
    show_progress_bar=False
)

# --- 5) Prédictions XGBoost ---
dtest_new = xgb.DMatrix(X_test_new)
y_scores_new = bst.predict(dtest_new)  # proba de la classe positive (VS si 1=VS)
y_pred_new = (y_scores_new >= 0.5).astype(int)  # seuil 0.5 (modifie si tu as un seuil optimal)

# --- 6) Affichage ---
classes = list(le.classes_) if le is not None else ["NVS","VS"]  # adapte si besoin
for i, phrase in enumerate(phrases_test):
    print(f"\nTexte : {phrase}")
    print(f"Texte nettoyé : {phrases_nettoyees[i]}")
    print(f"-> Score VS : {y_scores_new[i]:.4f}")
    print(f"-> Score NVS : {1 - y_scores_new[i]:.4f}")
    idx = y_pred_new[i]
    # si tes labels encodés sont (NVS=0, VS=1), ceci renverra bien VS/NVS
    print(f"-> Classe prédite : {classes[idx] if len(classes)==2 else ('VS' if idx==1 else 'NVS')}")
# Out:
# Texte : A mysterious disease was reported by the group and may be a new unknown illness.
# Texte nettoyé : mysterious disease reported group may new unknown illness
# -> Score VS : 0.9766
# -> Score NVS : 0.0234
# -> Classe prédite : VS
#
# Texte : The pest risk is high and this could target a certain block, said the group.
# Texte nettoyé : pest risk high could target certain block said group
# -> Score VS : 0.0267
# -> Score NVS : 0.9733
# -> Classe prédite : NVS

# %% [markdown]
# ### TF-IDF + XGBOOST reste meilleur jusqu'à présent même au niveau des tests sur des courtes phrases

# %% [markdown]
# ### Appliquons voir SBERT + MLP que nous avions appliqué à la pahse 1 du projet

# %%
# =========================
# 0) Imports & seed
# =========================
import os, numpy as np, pandas as pd, torch, torch.nn as nn, torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
from sentence_transformers import SentenceTransformer
from torch.utils.data import Dataset, DataLoader

SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# =========================
# 1) Charger tes données phase 2

df = data.copy()

# =========================
# 2) Encodage des labels + split
# =========================
le = LabelEncoder()
y = le.fit_transform(df['type_article'])
X_text = df["text_clean"].astype(str).tolist()

X_train_text, X_temp_text, y_train, y_temp = train_test_split(
    X_text, y, test_size=0.2, stratify=y, random_state=SEED
)
X_val_text, X_test_text, y_val, y_test = train_test_split(
    X_temp_text, y_temp, test_size=0.5, stratify=y_temp, random_state=SEED
)

num_classes = len(le.classes_)
print("Classes:", dict(zip(range(num_classes), le.classes_)))

# =========================
# 3) Embeddings SBERT (batched)
# =========================
sbert = SentenceTransformer('all-MiniLM-L6-v2', device=str(device))

def encode_texts(texts, batch_size=256):
    embs = []
    for i in range(0, len(texts), batch_size):
        batch = texts[i:i+batch_size]
        with torch.no_grad():
            emb = sbert.encode(batch, convert_to_numpy=True, show_progress_bar=False, batch_size=batch_size)
        embs.append(emb)
    return np.vstack(embs)

X_train_emb = encode_texts(X_train_text)
X_val_emb   = encode_texts(X_val_text)
X_test_emb  = encode_texts(X_test_text)

print("Dims:", X_train_emb.shape, X_val_emb.shape, X_test_emb.shape)  # (N, 384) pour all-MiniLM-L6-v2

# =========================
# 4) Torch Dataset / DataLoader
# =========================
class NumpyDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)
    def __len__(self): return len(self.y)
    def __getitem__(self, idx): return self.X[idx], self.y[idx]

train_ds = NumpyDataset(X_train_emb, y_train)
val_ds   = NumpyDataset(X_val_emb, y_val)
test_ds  = NumpyDataset(X_test_emb, y_test)

train_loader = DataLoader(train_ds, batch_size=128, shuffle=True,  drop_last=False)
val_loader   = DataLoader(val_ds,   batch_size=256, shuffle=False, drop_last=False)
test_loader  = DataLoader(test_ds,  batch_size=256, shuffle=False, drop_last=False)

# =========================
# 5) Modèle (ta classe)
# =========================
class SBERTClassifier(nn.Module):
    def __init__(self, embedding_dim, num_classes):
        super().__init__()
        self.classifier = nn.Sequential(
            nn.Linear(embedding_dim, 128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, num_classes)
        )
    def forward(self, x):
        return self.classifier(x)

model = SBERTClassifier(X_train_emb.shape[1], num_classes).to(device)

# =========================
# 6) Perte pondérée (déséquilibre) + optim
# =========================
# Comme nos classes sont déséquilibrées
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(num_classes),
    y=y_train
)
class_weights = torch.tensor(class_weights, dtype=torch.float32, device=device)
criterion = nn.CrossEntropyLoss(weight=class_weights)

optimizer = optim.Adam(model.parameters(), lr=1e-4)
# (Optionnel) scheduler si tu veux
# scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2)

# =========================
# 7) Entraînement avec early stopping (le tien)
# =========================
save_dir = "models"
os.makedirs(save_dir, exist_ok=True)
save_path = os.path.join(save_dir, "best_sbert_phase2.pt")

best_val_loss = np.inf
patience = 5
patience_counter = 0

history = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": [], "train_f1": [], "val_f1": []}
num_epochs = 100

for epoch in range(num_epochs):
    # ---- Train ----
    model.train()
    y_true_train, y_pred_train = [], []
    train_loss = 0.0

    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        logits = model(xb)
        loss = criterion(logits, yb)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        preds = logits.argmax(dim=1)
        y_true_train.extend(yb.detach().cpu().numpy())
        y_pred_train.extend(preds.detach().cpu().numpy())

    train_loss /= len(train_loader)
    train_acc = accuracy_score(y_true_train, y_pred_train)
    train_f1 = f1_score(y_true_train, y_pred_train, average='macro')

    # ---- Val ----
    model.eval()
    y_true_val, y_pred_val = [], []
    val_loss = 0.0

    with torch.no_grad():
        for xb, yb in val_loader:
            xb, yb = xb.to(device), yb.to(device)
            logits = model(xb)
            loss = criterion(logits, yb)
            val_loss += loss.item()
            preds = logits.argmax(dim=1)
            y_true_val.extend(yb.detach().cpu().numpy())
            y_pred_val.extend(preds.detach().cpu().numpy())

    val_loss /= len(val_loader)
    val_acc = accuracy_score(y_true_val, y_pred_val)
    val_f1 = f1_score(y_true_val, y_pred_val, average='macro')

    # scheduler.step(val_loss)  # si utilisé

    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["train_acc"].append(train_acc)
    history["val_acc"].append(val_acc)
    history["train_f1"].append(train_f1)
    history["val_f1"].append(val_f1)

    print(f"[{epoch+1:03d}/{num_epochs}] "
          f"Train Loss {train_loss:.4f} | Val Loss {val_loss:.4f} | "
          f"Train Acc {train_acc:.4f} | Val Acc {val_acc:.4f} | "
          f"Train F1 {train_f1:.4f} | Val F1 {val_f1:.4f}")

    # Early stopping
    if val_loss < best_val_loss - 1e-6:
        best_val_loss = val_loss
        torch.save(model.state_dict(), save_path)
        patience_counter = 0
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print("Early stopping déclenché.")
            break

print("Meilleur val_loss:", round(best_val_loss, 4))

# =========================
# 8) Rechargement & Évaluation test
# =========================
# --- Rechargement des poids 
state_dict = torch.load(save_path, map_location=device, weights_only=True)
model.load_state_dict(state_dict)


model.eval()
y_true_test, y_pred_test = [], []
with torch.no_grad():
    for xb, yb in test_loader:
        xb = xb.to(device)
        logits = model(xb)
        preds = logits.argmax(dim=1).cpu().numpy()
        y_pred_test.extend(preds)
        y_true_test.extend(yb.numpy())

test_acc = accuracy_score(y_true_test, y_pred_test)
test_f1 = f1_score(y_true_test, y_pred_test, average='macro')
print("\n== Évaluation Test ==")
print("Accuracy:", round(test_acc, 4))
print("Macro-F1:", round(test_f1, 4))
print("\nClassification report:")
print(classification_report(y_true_test, y_pred_test, target_names=le.classes_))

print("\nMatrice de confusion:\n", confusion_matrix(y_true_test, y_pred_test))

# =========================
# 9) Sauvegardes utiles
# =========================
# Sauvegarder l'encoder (utile au déploiement)
import joblib, json
joblib.dump(le, os.path.join(save_dir, "label_encoder.joblib"))
with open(os.path.join(save_dir, "train_history.json"), "w", encoding="utf-8") as f:
    json.dump(history, f, ensure_ascii=False, indent=2)
# Out:
# Device: cpu
# Classes: {0: 'NVS', 1: 'VS'}
# C:\Users\stginrae.AFRIQUE-TP02\AppData\Roaming\Python\Python312\site-packages\huggingface_hub\file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Dims: (1992, 384) (249, 384) (249, 384)
# [001/100] Train Loss 0.6927 | Val Loss 0.6873 | Train Acc 0.1034 | Val Acc 0.1004 | Train F1 0.0952 | Val F1 0.0912
# [002/100] Train Loss 0.6861 | Val Loss 0.6811 | Train Acc 0.1411 | Val Acc 0.2048 | Train F1 0.1383 | Val F1 0.2048
# [003/100] Train Loss 0.6800 | Val Loss 0.6744 | Train Acc 0.3072 | Val Acc 0.3815 | Train F1 0.2984 | Val F1 0.3606
# [004/100] Train Loss 0.6726 | Val Loss 0.6667 | Train Acc 0.4880 | Val Acc 0.5743 | Train F1 0.4372 | Val F1 0.5053
# [005/100] Train Loss 0.6643 | Val Loss 0.6577 | Train Acc 0.6330 | Val Acc 0.7028 | Train F1 0.5344 | Val F1 0.5891
# [006/100] Train Loss 0.6560 | Val Loss 0.6475 | Train Acc 0.7189 | Val Acc 0.7711 | Train F1 0.5916 | Val F1 0.6460
# [007/100] Train Loss 0.6437 | Val Loss 0.6360 | Train Acc 0.7856 | Val Acc 0.8112 | Train F1 0.6446 | Val F1 0.6840
# [008/100] Train Loss 0.6339 | Val Loss 0.6234 | Train Acc 0.8243 | Val Acc 0.8394 | Train F1 0.6814 | Val F1 0.7080
# [009/100] Train Loss 0.6191 | Val Loss 0.6101 | Train Acc 0.8409 | Val Acc 0.8514 | Train F1 0.6936 | Val F1 0.7158
# [010/100] Train Loss 0.6069 | Val Loss 0.5960 | Train Acc 0.8624 | Val Acc 0.8594 | Train F1 0.7211 | Val F1 0.7191
# [011/100] Train Loss 0.5923 | Val Loss 0.5818 | Train Acc 0.8700 | Val Acc 0.8675 | Train F1 0.7305 | Val F1 0.7224
# [012/100] Train Loss 0.5774 | Val Loss 0.5671 | Train Acc 0.8705 | Val Acc 0.8675 | Train F1 0.7304 | Val F1 0.7224
# [013/100] Train Loss 0.5630 | Val Loss 0.5528 | Train Acc 0.8735 | Val Acc 0.8635 | Train F1 0.7358 | Val F1 0.7240
# [014/100] Train Loss 0.5503 | Val Loss 0.5382 | Train Acc 0.8745 | Val Acc 0.8755 | Train F1 0.7371 | Val F1 0.7392
# [015/100] Train Loss 0.5359 | Val Loss 0.5243 | Train Acc 0.8690 | Val Acc 0.8675 | Train F1 0.7301 | Val F1 0.7290
# [016/100] Train Loss 0.5220 | Val Loss 0.5110 | Train Acc 0.8745 | Val Acc 0.8715 | Train F1 0.7371 | Val F1 0.7340
# [017/100] Train Loss 0.5086 | Val Loss 0.4976 | Train Acc 0.8765 | Val Acc 0.8715 | Train F1 0.7437 | Val F1 0.7340
# [018/100] Train Loss 0.4945 | Val Loss 0.4847 | Train Acc 0.8740 | Val Acc 0.8715 | Train F1 0.7412 | Val F1 0.7402
# [019/100] Train Loss 0.4835 | Val Loss 0.4727 | Train Acc 0.8755 | Val Acc 0.8675 | Train F1 0.7439 | Val F1 0.7351
# [020/100] Train Loss 0.4686 | Val Loss 0.4612 | Train Acc 0.8715 | Val Acc 0.8675 | Train F1 0.7417 | Val F1 0.7351
# [021/100] Train Loss 0.4624 | Val Loss 0.4503 | Train Acc 0.8795 | Val Acc 0.8675 | Train F1 0.7521 | Val F1 0.7351
# [022/100] Train Loss 0.4506 | Val Loss 0.4399 | Train Acc 0.8760 | Val Acc 0.8675 | Train F1 0.7490 | Val F1 0.7351
# [023/100] Train Loss 0.4395 | Val Loss 0.4300 | Train Acc 0.8775 | Val Acc 0.8675 | Train F1 0.7517 | Val F1 0.7351
# [024/100] Train Loss 0.4306 | Val Loss 0.4211 | Train Acc 0.8795 | Val Acc 0.8675 | Train F1 0.7536 | Val F1 0.7351
# [025/100] Train Loss 0.4172 | Val Loss 0.4122 | Train Acc 0.8820 | Val Acc 0.8675 | Train F1 0.7598 | Val F1 0.7351
# [026/100] Train Loss 0.4054 | Val Loss 0.4034 | Train Acc 0.8795 | Val Acc 0.8675 | Train F1 0.7572 | Val F1 0.7351
# [027/100] Train Loss 0.3960 | Val Loss 0.3958 | Train Acc 0.8795 | Val Acc 0.8675 | Train F1 0.7579 | Val F1 0.7351
# [028/100] Train Loss 0.3902 | Val Loss 0.3887 | Train Acc 0.8845 | Val Acc 0.8715 | Train F1 0.7646 | Val F1 0.7402
# [029/100] Train Loss 0.3818 | Val Loss 0.3816 | Train Acc 0.8835 | Val Acc 0.8675 | Train F1 0.7646 | Val F1 0.7351
# [030/100] Train Loss 0.3796 | Val Loss 0.3752 | Train Acc 0.8850 | Val Acc 0.8675 | Train F1 0.7646 | Val F1 0.7351
# [031/100] Train Loss 0.3756 | Val Loss 0.3697 | Train Acc 0.8825 | Val Acc 0.8675 | Train F1 0.7639 | Val F1 0.7351
# [032/100] Train Loss 0.3628 | Val Loss 0.3640 | Train Acc 0.8830 | Val Acc 0.8675 | Train F1 0.7652 | Val F1 0.7351
# [033/100] Train Loss 0.3512 | Val Loss 0.3592 | Train Acc 0.8790 | Val Acc 0.8715 | Train F1 0.7572 | Val F1 0.7402
# [034/100] Train Loss 0.3490 | Val Loss 0.3545 | Train Acc 0.8835 | Val Acc 0.8715 | Train F1 0.7653 | Val F1 0.7402
# [035/100] Train Loss 0.3480 | Val Loss 0.3499 | Train Acc 0.8850 | Val Acc 0.8795 | Train F1 0.7693 | Val F1 0.7507
# [036/100] Train Loss 0.3411 | Val Loss 0.3460 | Train Acc 0.8901 | Val Acc 0.8795 | Train F1 0.7742 | Val F1 0.7507
# [037/100] Train Loss 0.3365 | Val Loss 0.3418 | Train Acc 0.8881 | Val Acc 0.8835 | Train F1 0.7721 | Val F1 0.7561
# [038/100] Train Loss 0.3297 | Val Loss 0.3386 | Train Acc 0.8926 | Val Acc 0.8835 | Train F1 0.7790 | Val F1 0.7561
# [039/100] Train Loss 0.3270 | Val Loss 0.3349 | Train Acc 0.8906 | Val Acc 0.8876 | Train F1 0.7755 | Val F1 0.7673
# [040/100] Train Loss 0.3163 | Val Loss 0.3316 | Train Acc 0.8891 | Val Acc 0.8876 | Train F1 0.7754 | Val F1 0.7673
# [041/100] Train Loss 0.3151 | Val Loss 0.3282 | Train Acc 0.8911 | Val Acc 0.8916 | Train F1 0.7795 | Val F1 0.7729
# [042/100] Train Loss 0.3133 | Val Loss 0.3258 | Train Acc 0.8941 | Val Acc 0.8956 | Train F1 0.7824 | Val F1 0.7786
# [043/100] Train Loss 0.3164 | Val Loss 0.3229 | Train Acc 0.8916 | Val Acc 0.8956 | Train F1 0.7789 | Val F1 0.7786
# [044/100] Train Loss 0.3088 | Val Loss 0.3202 | Train Acc 0.8931 | Val Acc 0.8956 | Train F1 0.7829 | Val F1 0.7786
# [045/100] Train Loss 0.2990 | Val Loss 0.3180 | Train Acc 0.8891 | Val Acc 0.8956 | Train F1 0.7748 | Val F1 0.7786
# [046/100] Train Loss 0.3001 | Val Loss 0.3158 | Train Acc 0.8926 | Val Acc 0.8956 | Train F1 0.7809 | Val F1 0.7786
# [047/100] Train Loss 0.2901 | Val Loss 0.3134 | Train Acc 0.8956 | Val Acc 0.8956 | Train F1 0.7877 | Val F1 0.7786
# [048/100] Train Loss 0.2927 | Val Loss 0.3116 | Train Acc 0.8936 | Val Acc 0.8956 | Train F1 0.7836 | Val F1 0.7786
# [049/100] Train Loss 0.2918 | Val Loss 0.3103 | Train Acc 0.8986 | Val Acc 0.8956 | Train F1 0.7908 | Val F1 0.7786
# [050/100] Train Loss 0.2943 | Val Loss 0.3080 | Train Acc 0.8961 | Val Acc 0.8956 | Train F1 0.7872 | Val F1 0.7786
# [051/100] Train Loss 0.2866 | Val Loss 0.3056 | Train Acc 0.8961 | Val Acc 0.8996 | Train F1 0.7896 | Val F1 0.7897
# [052/100] Train Loss 0.2789 | Val Loss 0.3037 | Train Acc 0.8986 | Val Acc 0.8996 | Train F1 0.7914 | Val F1 0.7897
# [053/100] Train Loss 0.2803 | Val Loss 0.3022 | Train Acc 0.8966 | Val Acc 0.8996 | Train F1 0.7885 | Val F1 0.7897
# [054/100] Train Loss 0.2771 | Val Loss 0.3012 | Train Acc 0.8971 | Val Acc 0.8996 | Train F1 0.7905 | Val F1 0.7897
# [055/100] Train Loss 0.2728 | Val Loss 0.3000 | Train Acc 0.8991 | Val Acc 0.8996 | Train F1 0.7933 | Val F1 0.7897
# [056/100] Train Loss 0.2689 | Val Loss 0.2991 | Train Acc 0.9001 | Val Acc 0.8996 | Train F1 0.7948 | Val F1 0.7897
# [057/100] Train Loss 0.2625 | Val Loss 0.2986 | Train Acc 0.9036 | Val Acc 0.8996 | Train F1 0.8005 | Val F1 0.7844
# [058/100] Train Loss 0.2666 | Val Loss 0.2970 | Train Acc 0.9071 | Val Acc 0.9036 | Train F1 0.8034 | Val F1 0.7956
# [059/100] Train Loss 0.2667 | Val Loss 0.2965 | Train Acc 0.9076 | Val Acc 0.8996 | Train F1 0.8059 | Val F1 0.7844
# [060/100] Train Loss 0.2631 | Val Loss 0.2948 | Train Acc 0.9056 | Val Acc 0.9036 | Train F1 0.8035 | Val F1 0.7956
# [061/100] Train Loss 0.2592 | Val Loss 0.2935 | Train Acc 0.9021 | Val Acc 0.9036 | Train F1 0.7977 | Val F1 0.7956
# [062/100] Train Loss 0.2562 | Val Loss 0.2927 | Train Acc 0.8986 | Val Acc 0.9036 | Train F1 0.7938 | Val F1 0.7956
# [063/100] Train Loss 0.2569 | Val Loss 0.2930 | Train Acc 0.9056 | Val Acc 0.9076 | Train F1 0.8029 | Val F1 0.8017
# [064/100] Train Loss 0.2584 | Val Loss 0.2923 | Train Acc 0.9001 | Val Acc 0.9116 | Train F1 0.7936 | Val F1 0.8079
# [065/100] Train Loss 0.2505 | Val Loss 0.2903 | Train Acc 0.9036 | Val Acc 0.9076 | Train F1 0.8011 | Val F1 0.8017
# [066/100] Train Loss 0.2481 | Val Loss 0.2904 | Train Acc 0.9076 | Val Acc 0.9076 | Train F1 0.8065 | Val F1 0.8017
# [067/100] Train Loss 0.2473 | Val Loss 0.2897 | Train Acc 0.9056 | Val Acc 0.9116 | Train F1 0.8041 | Val F1 0.8079
# [068/100] Train Loss 0.2413 | Val Loss 0.2887 | Train Acc 0.9061 | Val Acc 0.9116 | Train F1 0.8037 | Val F1 0.8079
# [069/100] Train Loss 0.2444 | Val Loss 0.2878 | Train Acc 0.9071 | Val Acc 0.9076 | Train F1 0.8064 | Val F1 0.8017
# [070/100] Train Loss 0.2426 | Val Loss 0.2876 | Train Acc 0.9127 | Val Acc 0.9116 | Train F1 0.8159 | Val F1 0.8079
# [071/100] Train Loss 0.2422 | Val Loss 0.2866 | Train Acc 0.9111 | Val Acc 0.9076 | Train F1 0.8142 | Val F1 0.8017
# [072/100] Train Loss 0.2371 | Val Loss 0.2860 | Train Acc 0.9086 | Val Acc 0.9076 | Train F1 0.8098 | Val F1 0.8017
# [073/100] Train Loss 0.2423 | Val Loss 0.2877 | Train Acc 0.9147 | Val Acc 0.9116 | Train F1 0.8185 | Val F1 0.8079
# [074/100] Train Loss 0.2295 | Val Loss 0.2864 | Train Acc 0.9142 | Val Acc 0.9116 | Train F1 0.8166 | Val F1 0.8079
# [075/100] Train Loss 0.2324 | Val Loss 0.2857 | Train Acc 0.9132 | Val Acc 0.9116 | Train F1 0.8167 | Val F1 0.8079
# [076/100] Train Loss 0.2317 | Val Loss 0.2841 | Train Acc 0.9091 | Val Acc 0.9116 | Train F1 0.8094 | Val F1 0.8079
# [077/100] Train Loss 0.2336 | Val Loss 0.2852 | Train Acc 0.9101 | Val Acc 0.9116 | Train F1 0.8109 | Val F1 0.8079
# [078/100] Train Loss 0.2298 | Val Loss 0.2857 | Train Acc 0.9121 | Val Acc 0.9157 | Train F1 0.8140 | Val F1 0.8142
# [079/100] Train Loss 0.2350 | Val Loss 0.2847 | Train Acc 0.9127 | Val Acc 0.9157 | Train F1 0.8142 | Val F1 0.8142
# [080/100] Train Loss 0.2254 | Val Loss 0.2838 | Train Acc 0.9197 | Val Acc 0.9157 | Train F1 0.8264 | Val F1 0.8142
# [081/100] Train Loss 0.2282 | Val Loss 0.2835 | Train Acc 0.9132 | Val Acc 0.9157 | Train F1 0.8156 | Val F1 0.8142
# [082/100] Train Loss 0.2246 | Val Loss 0.2838 | Train Acc 0.9127 | Val Acc 0.9157 | Train F1 0.8165 | Val F1 0.8142
# [083/100] Train Loss 0.2201 | Val Loss 0.2847 | Train Acc 0.9142 | Val Acc 0.9157 | Train F1 0.8183 | Val F1 0.8142
# [084/100] Train Loss 0.2193 | Val Loss 0.2841 | Train Acc 0.9182 | Val Acc 0.9157 | Train F1 0.8246 | Val F1 0.8142
# [085/100] Train Loss 0.2248 | Val Loss 0.2838 | Train Acc 0.9142 | Val Acc 0.9157 | Train F1 0.8183 | Val F1 0.8142
# [086/100] Train Loss 0.2201 | Val Loss 0.2830 | Train Acc 0.9162 | Val Acc 0.9157 | Train F1 0.8220 | Val F1 0.8142
# [087/100] Train Loss 0.2221 | Val Loss 0.2832 | Train Acc 0.9152 | Val Acc 0.9157 | Train F1 0.8204 | Val F1 0.8142
# [088/100] Train Loss 0.2142 | Val Loss 0.2838 | Train Acc 0.9177 | Val Acc 0.9157 | Train F1 0.8254 | Val F1 0.8142
# [089/100] Train Loss 0.2149 | Val Loss 0.2834 | Train Acc 0.9182 | Val Acc 0.9157 | Train F1 0.8246 | Val F1 0.8142
# [090/100] Train Loss 0.2168 | Val Loss 0.2823 | Train Acc 0.9187 | Val Acc 0.9157 | Train F1 0.8270 | Val F1 0.8142
# [091/100] Train Loss 0.2142 | Val Loss 0.2830 | Train Acc 0.9162 | Val Acc 0.9157 | Train F1 0.8220 | Val F1 0.8142
# [092/100] Train Loss 0.2099 | Val Loss 0.2834 | Train Acc 0.9197 | Val Acc 0.9157 | Train F1 0.8281 | Val F1 0.8142
# [093/100] Train Loss 0.2111 | Val Loss 0.2834 | Train Acc 0.9202 | Val Acc 0.9157 | Train F1 0.8278 | Val F1 0.8142
# [094/100] Train Loss 0.2107 | Val Loss 0.2841 | Train Acc 0.9222 | Val Acc 0.9197 | Train F1 0.8316 | Val F1 0.8207
# [095/100] Train Loss 0.2074 | Val Loss 0.2829 | Train Acc 0.9212 | Val Acc 0.9157 | Train F1 0.8305 | Val F1 0.8142
# Early stopping déclenché.
# Meilleur val_loss: 0.2823
#
# == Évaluation Test ==
# Accuracy: 0.8675
# Macro-F1: 0.729
#
# Classification report:
#               precision    recall  f1-score   support
#
#          NVS       0.97      0.88      0.92       224
#           VS       0.41      0.76      0.54        25
#
#     accuracy                           0.87       249
#    macro avg       0.69      0.82      0.73       249
# weighted avg       0.91      0.87      0.88       249
#
#
# Matrice de confusion:
#  [[197  27]
#  [  6  19]]

# %%
import os
import json
import joblib
import numpy as np
import torch
import torch.nn as nn
from sentence_transformers import SentenceTransformer

# ==== 1) Paramètres / chemins ====
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
SAVE_DIR = "models"
MODEL_PATH = os.path.join(SAVE_DIR, "best_sbert_phase2.pt")       # state_dict uniquement
LE_PATH    = os.path.join(SAVE_DIR, "label_encoder.joblib")       # sauvegardé au train
CLASSES_JSON = os.path.join(SAVE_DIR, "classes.json")             # optionnel
SBERT_PATH = "models/sbert_all-MiniLM-L6-v2"                      # si tu l’as sauvegardé localement
# Sinon, mets le nom du modèle huggingface que tu as utilisé à l’entrainement:
# SBERT_PATH = "sentence-transformers/all-MiniLM-L6-v2"

# ==== 2) Même archi que durant le train ====
class SBERTClassifier(nn.Module):
    def __init__(self, embedding_dim, num_classes):
        super().__init__()
        self.classifier = nn.Sequential(
            nn.Linear(embedding_dim, 128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, num_classes)
        )
    def forward(self, x):
        return self.classifier(x)

# ==== 3) Charger label encoder & classes ====
le = joblib.load(LE_PATH)
classes = list(le.classes_)

# Si tu n’as pas le joblib sous la main mais un classes.json séparé :
if not classes and os.path.exists(CLASSES_JSON):
    with open(CLASSES_JSON, "r", encoding="utf-8") as f:
        classes = json.load(f)

# ==== 4) Charger SBERT ====
sbert = SentenceTransformer(SBERT_PATH, device=str(DEVICE))

# ==== 5) Reconstruire le modèle & charger les poids ====
# embedding_dim pour all-MiniLM-L6-v2 = 384 (si tu as utilisé un autre modèle, adapte)
embedding_dim = sbert.get_sentence_embedding_dimension()
num_classes = len(classes)

model = SBERTClassifier(embedding_dim, num_classes).to(DEVICE)
state_dict = torch.load(MODEL_PATH, map_location=DEVICE, weights_only=True)
model.load_state_dict(state_dict)
model.eval()

# ==== 6) Prétraitement identique au train ====
# Remplace par ta vraie fonction (celle utilisée au training)
def nettoyer_texte(text: str):
    # EXEMPLE minimal — à remplacer par ta version
    return " ".join(text.lower().split())

def preprocess_for_inference(texts):
    out = []
    for p in texts:
        tokens_or_str = nettoyer_texte(p)
        if isinstance(tokens_or_str, list):
            out.append(" ".join(tokens_or_str))
        else:
            out.append(tokens_or_str)
    return out

# ==== 7) Fonction d’inférence ====
@torch.no_grad()
def predict_texts(texts, batch_size=64, normalize_embeddings=False):
    """
    - texts: liste de chaînes
    - normalize_embeddings: doit matcher la valeur utilisée à l'entraînement (False si tu n'as rien modifié)
    Retourne: probs (N, C), preds_idx (N,), preds_labels (N,)
    """
    cleaned = preprocess_for_inference(texts)
    # Encodage SBERT
    embs = sbert.encode(
        cleaned,
        batch_size=batch_size,
        convert_to_numpy=True,
        normalize_embeddings=normalize_embeddings,
        show_progress_bar=False
    )
    # Passage modèle
    xb = torch.tensor(embs, dtype=torch.float32, device=DEVICE)
    logits = model(xb)
    probs = torch.softmax(logits, dim=1).cpu().numpy()
    preds_idx = probs.argmax(axis=1)
    preds_labels = [classes[i] for i in preds_idx]
    return cleaned, probs, preds_idx, preds_labels

# ==== 8) Exemple d’utilisation ====
phrases_test = [
    "A mysterious disease was reported by the group and may be a new unknown illness.",
    "The pest disease risk is high and this could target a certain block, said the group."
]

cleaned, probs, idx, labels = predict_texts(phrases_test, batch_size=64, normalize_embeddings=False)

# Affichage
for i, p in enumerate(phrases_test):
    print(f"\nTexte : {p}")
    print(f"Texte nettoyé : {cleaned[i]}")
    # Affiche les probas par classe (ordre = le.classes_)
    for c, pr in zip(classes, probs[i]):
        print(f"  P({c}) = {pr:.4f}")
    print(f"-> Classe prédite : {labels[i]}")
# Out:
# Texte : A mysterious disease was reported by the group and may be a new unknown illness.
# Texte nettoyé : a mysterious disease was reported by the group and may be a new unknown illness.
#   P(NVS) = 0.0357
#   P(VS) = 0.9643
# -> Classe prédite : VS
#
# Texte : The pest disease risk is high and this could target a certain block, said the group.
# Texte nettoyé : the pest disease risk is high and this could target a certain block, said the group.
#   P(NVS) = 0.6530
#   P(VS) = 0.3470
# -> Classe prédite : NVS

# %%
# Tracer les courbes d'apprentissage:
import matplotlib.pyplot as plt
plt.figure(); plt.plot(history["train_loss"]); plt.plot(history["val_loss"]); plt.title("Loss"); plt.legend(["train","val"]); plt.show()
plt.figure(); plt.plot(history["train_acc"]); plt.plot(history["val_acc"]); plt.title("Accuracy"); plt.legend(["train","val"]); plt.show()
plt.figure(); plt.plot(history["train_f1"]); plt.plot(history["val_f1"]); plt.title("Macro-F1"); plt.legend(["train","val"]); plt.show()

# %% [markdown]
# ### Nous avons fait plusieurs entrainements ainsi que des tests, avec et sans noms de maladies, nous avons remarqué que la courbe d'apprentissage est meilleures avec le modèle TF-IDF et XG-BOOST lorsqu'on conserve les noms de maladie que nous avons (déjà nous n'avons pas tous les noms de maladie car nous avons utilisé les données nettoyées de la phase 1), c'est le mot "disease" qui
#
# Nous allons donc devoir conserver ce modèle pour cette deuxième phase du stage
